# %% [markdown]
# # Rectification After Camera orientation correction using vanishing point estimation
# ### Author: Muhammad Rafi Faisal

# %%
import os                      
import cv2                     
import math                    
import numpy as np             
import random                  
import matplotlib.pyplot as plt

# %% [markdown]
# # Function for feature detection (Super Point), matching (Super Glue), and RANSAC-based pose estimation
# source: https://github.com/magicleap/SuperGluePretrainedNetwork

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
from models.superpoint import SuperPoint
from models.superglue import SuperGlue


def visualize_matches(img1, img2, points1, points2, inlier_mask):
    if len(img1.shape) == 2:
        img1 = cv2.cvtColor(img1, cv2.COLOR_GRAY2BGR)
    if len(img2.shape) == 2:
        img2 = cv2.cvtColor(img2, cv2.COLOR_GRAY2BGR)

    h1, w1 = img1.shape[:2]
    h2, w2 = img2.shape[:2]
    height = max(h1, h2)
    width = w1 + w2
    combined = np.zeros((height, width, 3), dtype=np.uint8)
    combined[:h1, :w1] = img1
    combined[:h2, w1:w1+w2] = img2

    for i in range(len(points1)):
        pt1 = (int(points1[i][0]), int(points1[i][1]))
        pt2 = (int(points2[i][0] + w1), int(points2[i][1]))
        color = (0, 255, 0) if inlier_mask[i] else (0, 0, 255)
        cv2.line(combined, pt1, pt2, color, 1)
        cv2.circle(combined, pt1, 2, color, -1)
        cv2.circle(combined, pt2, 2, color, -1)
        
    plt.figure(figsize=(12, 6))
    plt.imshow(cv2.cvtColor(combined, cv2.COLOR_BGR2RGB))
    plt.title("Matches: Green = Inliers, Red = Outliers")
    plt.axis('off')
    plt.show()


def feature_detection_and_matching(images0, images1):
    all_points_1 = []
    all_points_2 = []
    
    for i in range(len(images1)):
        img1, img2 = images0[i], images1[i]

        # Detect features using SuperPoint
        kp1, desc1, _ = detect_features_with_superpoint(img1)
        kp2, desc2, _ = detect_features_with_superpoint(img2)

        # Match features using SuperGlue
        points_1, points_2 = match_features_with_superglue(kp1, desc1, img1, kp2, desc2, img2)

        if len(points_1) < 8 or len(points_2) < 8:
            print(f"Not enough matches found for Image Pair: {i}")
            continue
            
        all_points_1.append(points_1)
        all_points_2.append(points_2)
    
    return all_points_1, all_points_2

# %% [markdown]
# # Running with SUPER POINT and GLUE

# %%
import itertools
import torch
import numpy as np
import cv2
from models.superpoint import SuperPoint
from models.superglue import SuperGlue

# Initialize device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load SuperPoint & SuperGlue models
config = {
    'superpoint': {'nms_radius': 4, 'keypoint_threshold': 0.005, 'max_keypoints': -1}, # threshold 0.001/0.005
    'superglue': {'weights': 'indoor', 'sinkhorn_iterations': 20} # changing now weights from "indoor" to "outdoor"
}
superpoint = SuperPoint(config['superpoint']).to(device).eval()
superglue = SuperGlue(config['superglue']).to(device).eval()

feature_detectors = [
    superpoint,
]

feature_matchers = [
    superglue, 
]

# Camera matrix (adjust based on dataset)
# camera_matrix = np.array([   # Budapest dataset
#     [1250, 0, 960],
#     [0, 1250, 600],
#     [0, 0, 1]
# ])

# camera_matrix = np.array([[718.856,    0,    607.1928], #kitti
#  [  0,     718.856,  185.2157],
#  [  0,       0,       1    ]])

results, results_a, results_b = [], [], []
points3d_list, points2d_list, pose_list = [], [], []

def detect_features_with_superpoint(image):
    #Extracts keypoints & descriptors using SuperPoint
    if len(image.shape) == 3 and image.shape[2] == 3:
        image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        image_gray = image
        
    # image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image_tensor = torch.from_numpy(image_gray).float()[None, None] / 255.0  # Normalize
    image_tensor = image_tensor.to(device)

    with torch.no_grad():
        outputs = superpoint({'image': image_tensor})

    keypoints = outputs['keypoints'][0].cpu().numpy()
    descriptors = outputs['descriptors'][0].cpu().numpy()
    scores = outputs['scores'][0].cpu().numpy()
    print(f"Detected {len(keypoints)} keypoints")
    return keypoints, descriptors, scores

def match_features_with_superglue(kp1, desc1, img1, kp2, desc2, img2):
    # Convert images to grayscale and normalize; shape: [1, 1, H, W]
    if len(img1.shape) == 3 and img1.shape[2] == 3:
        img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2_gray = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
    else:
        img1_gray = img1
        img2_gray = img2
    # img1_gray = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
    # img2_gray = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
    img1_tensor = torch.from_numpy(img1_gray).float()[None, None] / 255.0
    img2_tensor = torch.from_numpy(img2_gray).float()[None, None] / 255.0
    img1_tensor = img1_tensor.to(device)
    img2_tensor = img2_tensor.to(device)
    
    # Create data dictionary with actual images
    data = {
        'image0': img1_tensor,
        'image1': img2_tensor,
        'keypoints0': torch.tensor(kp1, dtype=torch.float32)[None].to(device),
        'keypoints1': torch.tensor(kp2, dtype=torch.float32)[None].to(device),
        'descriptors0': torch.tensor(desc1, dtype=torch.float32)[None].to(device),
        'descriptors1': torch.tensor(desc2, dtype=torch.float32)[None].to(device),
        'scores0': torch.ones((1, kp1.shape[0]), device=device),
        'scores1': torch.ones((1, kp2.shape[0]), device=device)
    }
    
    with torch.no_grad():
        outputs = superglue(data)
    
    matches = outputs['matches0'][0].cpu().numpy()
    valid_matches = matches > -1
    num_matches = valid_matches.sum()
    print(f"Found {num_matches} valid matches")
    
    if num_matches == 0:
        return np.empty((0, 2)), np.empty((0, 2))
    
    matched_kp1 = kp1[valid_matches]
    matched_kp2 = kp2[matches[valid_matches]]
    
    return matched_kp1, matched_kp2



# for feature_detector, matcher in itertools.product(feature_detectors, feature_matchers):
#     try:
#         result, result_a, result_b= feature_detection_and_matching(images0, images1)

#         results.append((feature_detector, matcher, result))
#         results_a.append((feature_detector, matcher, result_a))
#         results_b.append((feature_detector, matcher, result_b))

#     except Exception as e:
#         print(f"Error with combination: {feature_detector} and {matcher}: {e}")
# Out:
# /home/rafi/1_vanishing_point_est/SuperGluePretrainedNetwork/models/superpoint.py:137: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(str(path)))
# Loaded SuperPoint model
# Loaded SuperGlue model ("indoor" weights)
# /home/rafi/1_vanishing_point_est/SuperGluePretrainedNetwork/models/superglue.py:226: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(str(path)))

# %%
import numpy as np
# import cv2 as cv
from matplotlib import pyplot as plt
import sys
import glob

#Draw epipolar lines:
#
#img1: first image
#img1: second image
#
#lines: corresponding epilines
#pts1: point in first image
#pts2: point in second image
#
#colors: array of random colors for visualization
#
#Return: img1, img2 original images with drawn epilines

def drawlines(img1,img2,lines,pts1,pts2,colors,F):
    ''' img1 - image on which we draw the epilines for the points in img2
        lines - corresponding epilines '''

    print(img1.shape)

#r: image height
#c: image width
    r,c  = img1.shape
    img1 = cv2.cvtColor(img1,cv2.COLOR_GRAY2BGR)
    img2 = cv2.cvtColor(img2,cv2.COLOR_GRAY2BGR)
    cnt=0;
    for r,pt1,pt2 in zip(lines,pts1,pts2):
        color=colors[cnt,:].tolist()

#Get points in homogeneous form
        pt1Hom=np.ones(3);
        pt1Hom[0]=pt1[0]
        pt1Hom[1]=pt1[1]

        pt2Hom=np.ones(3);
        pt2Hom[0]=pt2[0]
        pt2Hom[1]=pt2[1]

#Compute epipolar lines in the first image
#        r1=F@pt1Hom
        r1=F.transpose()@pt2Hom

        x0,y0 = map(int, [0, -r1[2]/r1[1] ])
        x1,y1 = map(int, [c, -(r1[2]+r1[0]*c)/r1[1] ])

#Draw epipolar line
        img1 = cv2.line(img1, (x0,y0), (x1,y1), color,1)
#Draw feature point location
        img1 = cv2.circle(img1,tuple(pt1),5,color,-1)
        img2 = cv2.circle(img2,tuple(pt2),5,color,-1)
        cnt=cnt+1
    return img1,img2

# %% [markdown]
# ## For single img

# %%
#Load image
# fileName1=sys.argv[1]
# fileName2=sys.argv[2]

img1 = cv2.imread('../../dataset_budapest/elte_car_stereo/dev0_70_520/Dev0_Image_w1920_h1200_fn457.jpg', cv2.IMREAD_GRAYSCALE)  #queryimage # left image #, cv.IMREAD_GRAYSCALE
img2 = cv2.imread('../../dataset_budapest/elte_car_stereo/dev1_70_520/Dev1_Image_w1920_h1200_fn457.jpg', cv2.IMREAD_GRAYSCALE) #trainimage # right image
# LEFT_PATH  = "../../dataset_budapest/elte_car_stereo/dev0_70_520/Dev0_Image_w1920_h1200_fn100.jpg"
# RIGHT_PATH = "../../dataset_budapest/elte_car_stereo/dev1_70_520/Dev1_Image_w1920_h1200_fn100.jpg"
# img1 = cv2.imread('../output/dataset_2/img_l_corr/Dev0_Image_w1920_h1200_fn130.jpg', cv2.IMREAD_GRAYSCALE)  #queryimage # left image #, cv.IMREAD_GRAYSCALE
# img2 = cv2.imread('../output/dataset_2/img_r_corr/Dev1_Image_w1920_h1200_fn130.jpg', cv2.IMREAD_GRAYSCALE) #trainimage # right image

#img1 = cv.imread('Dev0_Image_w1920_h1200_fn400.jpg', cv.IMREAD_GRAYSCALE)  #queryimage # left image
#img2 = cv.imread('Dev1_Image_w1920_h1200_fn400.jpg', cv.IMREAD_GRAYSCALE) #trainimage # right image

pts1 = []
pts2 = []
#Apply SIFT feature detection
#Also retreive the desriptiors
pts1, pts2 = feature_detection_and_matching([img1], [img2])

pts1= np.int32(pts1[0])
pts2 = np.int32(pts2[0])


#Estimate fundamental matrix using RANSAC.
#(Point normalization included)
F, mask = cv2.findFundamentalMat(pts1,pts2,cv2.FM_RANSAC)
# We select only inlier points
pts1 = pts1[mask.ravel()==1]
pts2 = pts2[mask.ravel()==1]


#Number of inliers:

NUM_INLIERS=pts1.shape[0]

#Generate random colorrs for visualization
colors=np.zeros((NUM_INLIERS,3))
for idx in range(0,NUM_INLIERS):
    colors[idx,0]=np.random.randint(0,255)
    colors[idx,1]=np.random.randint(0,255)
    colors[idx,2]=np.random.randint(0,255)


# Find epilines corresponding to points in right image (second image) and
# drawing its lines on left image
lines1 = cv2.computeCorrespondEpilines(pts2.reshape(-1,1,2), 2,F)
lines1 = lines1.reshape(-1,3)
img5,img6 = drawlines(img1,img2,lines1,pts1,pts2,colors,F)


# Find epilines corresponding to points in left image (first image) and
# drawing its lines on right image
lines2 = cv2.computeCorrespondEpilines(pts1.reshape(-1,1,2), 1,F)
lines2 = lines2.reshape(-1,3)
img3,img4 = drawlines(img2,img1,lines2,pts2,pts1,colors,F.transpose())

# cv.imshow("Matches", img5)
# cv.waitKey(30000)

cv2.imwrite("rect_results/EpipLines1.png",img3)
cv2.imwrite("rect_results/Features1.png",img4)
cv2.imwrite("rect_results/EpipLines2.png",img5)
cv2.imwrite("rect_results/Features2.png",img6)


np.savetxt("rect_results/F_RANSAC.mat",F)
np.savetxt("rect_results/pts1.mat",pts1)
np.savetxt("rect_results/pts2.mat",pts2)
# Out:
# Detected 2962 keypoints
# Detected 1731 keypoints
# Found 172 valid matches
# (1200, 1920)
# (1200, 1920)

# %% [markdown]
# ## For all images

# %%
img_l_files = sorted(glob.glob('../../dataset_budapest/elte_car_stereo/dev0_70_520/*.jpg'))
img_r_files = sorted(glob.glob('../../dataset_budapest/elte_car_stereo/dev1_70_520/*.jpg'))

for i in range(len(img_l_files)):
    # Read images in grayscale
    img1 = cv2.imread(img_l_files[i], cv2.IMREAD_GRAYSCALE)
    img2 = cv2.imread(img_r_files[i], cv2.IMREAD_GRAYSCALE)
    
    if img1 is None or img2 is None:
        print(f"Error reading image pair {i}")
        continue

    # Get feature points from both images
    pts1_list, pts2_list = feature_detection_and_matching([img1], [img2])
    pts1 = pts1_list[0]
    pts2 = pts2_list[0]
    
    # Ensure there are enough points for estimation
    if len(pts1) < 8 or len(pts2) < 8:
        print(f"Not enough feature matches for pair {i}")
        continue

    pts1 = np.int32(pts1)
    pts2 = np.int32(pts2)

    # Estimate the fundamental matrix using RANSAC
    F, mask = cv2.findFundamentalMat(pts1, pts2, cv2.FM_RANSAC)
    pts1 = pts1[mask.ravel() == 1]
    pts2 = pts2[mask.ravel() == 1]

    # Number of inliers:
    NUM_INLIERS = pts1.shape[0]
    if NUM_INLIERS == 0:
        print(f"No inliers found for pair {i}")
        continue

    # Generate random colors for each inlier point
    colors = np.random.randint(0, 255, (NUM_INLIERS, 3))

    # Compute epipolar lines for each image
    lines1 = cv2.computeCorrespondEpilines(pts2.reshape(-1,1,2), 2, F)
    lines1 = lines1.reshape(-1,3)
    img_epilines1, img_features1 = drawlines(img1, img2, lines1, pts1, pts2, colors, F)

    lines2 = cv2.computeCorrespondEpilines(pts1.reshape(-1,1,2), 1, F)
    lines2 = lines2.reshape(-1,3)
    img_epilines2, img_features2 = drawlines(img2, img1, lines2, pts2, pts1, colors, F.transpose())

    # Save results as images
    output_dir = "rect_results"
    # cv2.imwrite(f"{output_dir}/EpipLines1_pair_{i}.png", img_epilines1)
    # cv2.imwrite(f"{output_dir}/Features1_pair_{i}.png", img_features1)
    # cv2.imwrite(f"{output_dir}/EpipLines2_pair_{i}.png", img_epilines2)
    # cv2.imwrite(f"{output_dir}/Features2_pair_{i}.png", img_features2)

    # Save fundamental matrix and feature points as text files
    np.savetxt(f"{output_dir}/F_RANSAC_pair_{i}.txt", F)
    np.savetxt(f"{output_dir}/pts1_pair_{i}.txt", pts1)
    np.savetxt(f"{output_dir}/pts2_pair_{i}.txt", pts2)

    print(f"Processed pair {i}: saved images and txt files.")
# Out:
# Detected 6794 keypoints
# Detected 3976 keypoints
# Found 2402 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 0: saved images and txt files.
# Detected 6956 keypoints
# Detected 3951 keypoints
# Found 2477 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 1: saved images and txt files.
# Detected 6942 keypoints
# Detected 4029 keypoints
# Found 2501 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 2: saved images and txt files.
# Detected 7129 keypoints
# Detected 4009 keypoints
# Found 2482 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 3: saved images and txt files.
# Detected 7152 keypoints
# Detected 4002 keypoints
# Found 2448 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 4: saved images and txt files.
# Detected 7121 keypoints
# Detected 3994 keypoints
# Found 2538 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 5: saved images and txt files.
# Detected 7096 keypoints
# Detected 4034 keypoints
# Found 2411 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 6: saved images and txt files.
# Detected 6934 keypoints
# Detected 4086 keypoints
# Found 2459 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 7: saved images and txt files.
# Detected 6975 keypoints
# Detected 4042 keypoints
# Found 2432 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 8: saved images and txt files.
# Detected 6948 keypoints
# Detected 3987 keypoints
# Found 2210 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 9: saved images and txt files.
# Detected 6964 keypoints
# Detected 3843 keypoints
# Found 2136 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 10: saved images and txt files.
# Detected 7060 keypoints
# Detected 3901 keypoints
# Found 2297 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 11: saved images and txt files.
# Detected 7169 keypoints
# Detected 4021 keypoints
# Found 2248 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 12: saved images and txt files.
# Detected 7145 keypoints
# Detected 4049 keypoints
# Found 2311 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 13: saved images and txt files.
# Detected 7030 keypoints
# Detected 4017 keypoints
# Found 2247 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 14: saved images and txt files.
# Detected 6899 keypoints
# Detected 4034 keypoints
# Found 2414 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 15: saved images and txt files.
# Detected 6950 keypoints
# Detected 3983 keypoints
# Found 2459 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 16: saved images and txt files.
# Detected 6821 keypoints
# Detected 4152 keypoints
# Found 2608 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 17: saved images and txt files.
# Detected 6948 keypoints
# Detected 4117 keypoints
# Found 2357 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 18: saved images and txt files.
# Detected 7005 keypoints
# Detected 4077 keypoints
# Found 2295 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 19: saved images and txt files.
# Detected 7062 keypoints
# Detected 4130 keypoints
# Found 2244 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 20: saved images and txt files.
# Detected 6911 keypoints
# Detected 3880 keypoints
# Found 2011 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 21: saved images and txt files.
# Detected 7003 keypoints
# Detected 3800 keypoints
# Found 2075 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 22: saved images and txt files.
# Detected 7033 keypoints
# Detected 3848 keypoints
# Found 2135 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 23: saved images and txt files.
# Detected 7059 keypoints
# Detected 3927 keypoints
# Found 2173 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 24: saved images and txt files.
# Detected 7070 keypoints
# Detected 3857 keypoints
# Found 2088 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 25: saved images and txt files.
# Detected 7100 keypoints
# Detected 3841 keypoints
# Found 2001 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 26: saved images and txt files.
# Detected 6955 keypoints
# Detected 3897 keypoints
# Found 1702 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 27: saved images and txt files.
# Detected 6889 keypoints
# Detected 3987 keypoints
# Found 2001 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 28: saved images and txt files.
# Detected 6891 keypoints
# Detected 3940 keypoints
# Found 1953 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 29: saved images and txt files.
# Detected 6928 keypoints
# Detected 4039 keypoints
# Found 2063 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 30: saved images and txt files.
# Detected 7114 keypoints
# Detected 4094 keypoints
# Found 2266 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 31: saved images and txt files.
# Detected 7218 keypoints
# Detected 4158 keypoints
# Found 2133 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 32: saved images and txt files.
# Detected 7090 keypoints
# Detected 4102 keypoints
# Found 2181 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 33: saved images and txt files.
# Detected 7140 keypoints
# Detected 3980 keypoints
# Found 1925 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 34: saved images and txt files.
# Detected 7105 keypoints
# Detected 4129 keypoints
# Found 2112 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 35: saved images and txt files.
# Detected 7009 keypoints
# Detected 4154 keypoints
# Found 1998 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 36: saved images and txt files.
# Detected 6921 keypoints
# Detected 4042 keypoints
# Found 1819 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 37: saved images and txt files.
# Detected 7027 keypoints
# Detected 4000 keypoints
# Found 1931 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 38: saved images and txt files.
# Detected 6918 keypoints
# Detected 3897 keypoints
# Found 1943 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 39: saved images and txt files.
# Detected 6818 keypoints
# Detected 3899 keypoints
# Found 1769 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 40: saved images and txt files.
# Detected 6915 keypoints
# Detected 3739 keypoints
# Found 1687 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 41: saved images and txt files.
# Detected 6911 keypoints
# Detected 3579 keypoints
# Found 1734 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 42: saved images and txt files.
# Detected 6865 keypoints
# Detected 3631 keypoints
# Found 1901 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 43: saved images and txt files.
# Detected 6834 keypoints
# Detected 3613 keypoints
# Found 2056 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 44: saved images and txt files.
# Detected 6990 keypoints
# Detected 3756 keypoints
# Found 1845 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 45: saved images and txt files.
# Detected 7059 keypoints
# Detected 3815 keypoints
# Found 1939 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 46: saved images and txt files.
# Detected 7072 keypoints
# Detected 3970 keypoints
# Found 1819 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 47: saved images and txt files.
# Detected 7097 keypoints
# Detected 4002 keypoints
# Found 1671 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 48: saved images and txt files.
# Detected 6934 keypoints
# Detected 3937 keypoints
# Found 1854 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 49: saved images and txt files.
# Detected 6697 keypoints
# Detected 4059 keypoints
# Found 2169 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 50: saved images and txt files.
# Detected 6566 keypoints
# Detected 4088 keypoints
# Found 2431 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 51: saved images and txt files.
# Detected 6367 keypoints
# Detected 3990 keypoints
# Found 2474 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 52: saved images and txt files.
# Detected 6418 keypoints
# Detected 3989 keypoints
# Found 2531 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 53: saved images and txt files.
# Detected 6279 keypoints
# Detected 3736 keypoints
# Found 2326 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 54: saved images and txt files.
# Detected 6002 keypoints
# Detected 3678 keypoints
# Found 2290 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 55: saved images and txt files.
# Detected 5900 keypoints
# Detected 3694 keypoints
# Found 2235 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 56: saved images and txt files.
# Detected 5922 keypoints
# Detected 3653 keypoints
# Found 2327 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 57: saved images and txt files.
# Detected 5797 keypoints
# Detected 3422 keypoints
# Found 2244 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 58: saved images and txt files.
# Detected 5446 keypoints
# Detected 3270 keypoints
# Found 2271 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 59: saved images and txt files.
# Detected 5194 keypoints
# Detected 3151 keypoints
# Found 2267 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 60: saved images and txt files.
# Detected 5176 keypoints
# Detected 2776 keypoints
# Found 2007 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 61: saved images and txt files.
# Detected 5434 keypoints
# Detected 2920 keypoints
# Found 2050 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 62: saved images and txt files.
# Detected 5568 keypoints
# Detected 2900 keypoints
# Found 2057 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 63: saved images and txt files.
# Detected 5886 keypoints
# Detected 2931 keypoints
# Found 2068 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 64: saved images and txt files.
# Detected 5981 keypoints
# Detected 3106 keypoints
# Found 1979 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 65: saved images and txt files.
# Detected 6115 keypoints
# Detected 3208 keypoints
# Found 1991 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 66: saved images and txt files.
# Detected 6143 keypoints
# Detected 3132 keypoints
# Found 1996 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 67: saved images and txt files.
# Detected 5929 keypoints
# Detected 3102 keypoints
# Found 2051 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 68: saved images and txt files.
# Detected 5794 keypoints
# Detected 2979 keypoints
# Found 1999 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 69: saved images and txt files.
# Detected 5686 keypoints
# Detected 2994 keypoints
# Found 1878 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 70: saved images and txt files.
# Detected 5696 keypoints
# Detected 2988 keypoints
# Found 1899 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 71: saved images and txt files.
# Detected 5631 keypoints
# Detected 2985 keypoints
# Found 1778 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 72: saved images and txt files.
# Detected 5741 keypoints
# Detected 2976 keypoints
# Found 1722 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 73: saved images and txt files.
# Detected 5674 keypoints
# Detected 3094 keypoints
# Found 1767 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 74: saved images and txt files.
# Detected 5847 keypoints
# Detected 3126 keypoints
# Found 1827 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 75: saved images and txt files.
# Detected 5935 keypoints
# Detected 3186 keypoints
# Found 1805 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 76: saved images and txt files.
# Detected 5990 keypoints
# Detected 3195 keypoints
# Found 1705 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 77: saved images and txt files.
# Detected 6137 keypoints
# Detected 3281 keypoints
# Found 1553 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 78: saved images and txt files.
# Detected 6260 keypoints
# Detected 3215 keypoints
# Found 1468 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 79: saved images and txt files.
# Detected 6376 keypoints
# Detected 3097 keypoints
# Found 1471 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 80: saved images and txt files.
# Detected 6423 keypoints
# Detected 3064 keypoints
# Found 1484 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 81: saved images and txt files.
# Detected 6366 keypoints
# Detected 3025 keypoints
# Found 1538 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 82: saved images and txt files.
# Detected 6201 keypoints
# Detected 2898 keypoints
# Found 1281 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 83: saved images and txt files.
# Detected 6432 keypoints
# Detected 2679 keypoints
# Found 1207 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 84: saved images and txt files.
# Detected 6799 keypoints
# Detected 2424 keypoints
# Found 1221 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 85: saved images and txt files.
# Detected 7163 keypoints
# Detected 2401 keypoints
# Found 1329 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 86: saved images and txt files.
# Detected 7447 keypoints
# Detected 2365 keypoints
# Found 1594 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 87: saved images and txt files.
# Detected 7218 keypoints
# Detected 3118 keypoints
# Found 2306 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 88: saved images and txt files.
# Detected 7346 keypoints
# Detected 3581 keypoints
# Found 2872 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 89: saved images and txt files.
# Detected 7597 keypoints
# Detected 3738 keypoints
# Found 2920 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 90: saved images and txt files.
# Detected 7613 keypoints
# Detected 3719 keypoints
# Found 2778 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 91: saved images and txt files.
# Detected 7578 keypoints
# Detected 3647 keypoints
# Found 2596 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 92: saved images and txt files.
# Detected 6925 keypoints
# Detected 3497 keypoints
# Found 2373 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 93: saved images and txt files.
# Detected 6320 keypoints
# Detected 3135 keypoints
# Found 2024 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 94: saved images and txt files.
# Detected 5850 keypoints
# Detected 2911 keypoints
# Found 1490 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 95: saved images and txt files.
# Detected 5733 keypoints
# Detected 2716 keypoints
# Found 1237 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 96: saved images and txt files.
# Detected 5764 keypoints
# Detected 2599 keypoints
# Found 1199 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 97: saved images and txt files.
# Detected 5608 keypoints
# Detected 2582 keypoints
# Found 1188 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 98: saved images and txt files.
# Detected 5538 keypoints
# Detected 2523 keypoints
# Found 1365 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 99: saved images and txt files.
# Detected 5527 keypoints
# Detected 2535 keypoints
# Found 1453 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 100: saved images and txt files.
# Detected 5537 keypoints
# Detected 2521 keypoints
# Found 1524 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 101: saved images and txt files.
# Detected 5403 keypoints
# Detected 2559 keypoints
# Found 1587 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 102: saved images and txt files.
# Detected 5493 keypoints
# Detected 2477 keypoints
# Found 1522 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 103: saved images and txt files.
# Detected 5411 keypoints
# Detected 2506 keypoints
# Found 1616 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 104: saved images and txt files.
# Detected 5396 keypoints
# Detected 2555 keypoints
# Found 1724 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 105: saved images and txt files.
# Detected 5446 keypoints
# Detected 2580 keypoints
# Found 1572 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 106: saved images and txt files.
# Detected 5475 keypoints
# Detected 2626 keypoints
# Found 1666 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 107: saved images and txt files.
# Detected 5545 keypoints
# Detected 2710 keypoints
# Found 1820 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 108: saved images and txt files.
# Detected 5495 keypoints
# Detected 2699 keypoints
# Found 1711 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 109: saved images and txt files.
# Detected 5494 keypoints
# Detected 2755 keypoints
# Found 1748 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 110: saved images and txt files.
# Detected 5590 keypoints
# Detected 2779 keypoints
# Found 1743 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 111: saved images and txt files.
# Detected 5666 keypoints
# Detected 2874 keypoints
# Found 1661 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 112: saved images and txt files.
# Detected 5584 keypoints
# Detected 2853 keypoints
# Found 1735 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 113: saved images and txt files.
# Detected 5579 keypoints
# Detected 2753 keypoints
# Found 1555 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 114: saved images and txt files.
# Detected 5802 keypoints
# Detected 2774 keypoints
# Found 1551 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 115: saved images and txt files.
# Detected 5888 keypoints
# Detected 2696 keypoints
# Found 1353 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 116: saved images and txt files.
# Detected 5981 keypoints
# Detected 2812 keypoints
# Found 1567 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 117: saved images and txt files.
# Detected 6254 keypoints
# Detected 2718 keypoints
# Found 1412 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 118: saved images and txt files.
# Detected 6362 keypoints
# Detected 2787 keypoints
# Found 1365 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 119: saved images and txt files.
# Detected 6112 keypoints
# Detected 2928 keypoints
# Found 1559 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 120: saved images and txt files.
# Detected 6265 keypoints
# Detected 3117 keypoints
# Found 1810 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 121: saved images and txt files.
# Detected 6501 keypoints
# Detected 3100 keypoints
# Found 1221 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 122: saved images and txt files.
# Detected 6677 keypoints
# Detected 3119 keypoints
# Found 894 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 123: saved images and txt files.
# Detected 6151 keypoints
# Detected 2871 keypoints
# Found 921 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 124: saved images and txt files.
# Detected 5978 keypoints
# Detected 3039 keypoints
# Found 1196 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 125: saved images and txt files.
# Detected 6093 keypoints
# Detected 3053 keypoints
# Found 887 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 126: saved images and txt files.
# Detected 6316 keypoints
# Detected 2928 keypoints
# Found 1010 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 127: saved images and txt files.
# Detected 6181 keypoints
# Detected 2924 keypoints
# Found 1026 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 128: saved images and txt files.
# Detected 5894 keypoints
# Detected 3330 keypoints
# Found 1322 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 129: saved images and txt files.
# Detected 5822 keypoints
# Detected 3468 keypoints
# Found 989 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 130: saved images and txt files.
# Detected 5656 keypoints
# Detected 3011 keypoints
# Found 836 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 131: saved images and txt files.
# Detected 5693 keypoints
# Detected 2964 keypoints
# Found 459 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 132: saved images and txt files.
# Detected 6029 keypoints
# Detected 3012 keypoints
# Found 982 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 133: saved images and txt files.
# Detected 6500 keypoints
# Detected 3080 keypoints
# Found 922 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 134: saved images and txt files.
# Detected 6376 keypoints
# Detected 3148 keypoints
# Found 1533 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 135: saved images and txt files.
# Detected 6028 keypoints
# Detected 3058 keypoints
# Found 1212 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 136: saved images and txt files.
# Detected 5507 keypoints
# Detected 3124 keypoints
# Found 963 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 137: saved images and txt files.
# Detected 5494 keypoints
# Detected 3008 keypoints
# Found 816 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 138: saved images and txt files.
# Detected 5563 keypoints
# Detected 2835 keypoints
# Found 596 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 139: saved images and txt files.
# Detected 5611 keypoints
# Detected 3009 keypoints
# Found 712 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 140: saved images and txt files.
# Detected 5938 keypoints
# Detected 3280 keypoints
# Found 985 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 141: saved images and txt files.
# Detected 6015 keypoints
# Detected 3150 keypoints
# Found 857 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 142: saved images and txt files.
# Detected 5909 keypoints
# Detected 2995 keypoints
# Found 840 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 143: saved images and txt files.
# Detected 5895 keypoints
# Detected 3063 keypoints
# Found 1055 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 144: saved images and txt files.
# Detected 6135 keypoints
# Detected 3217 keypoints
# Found 1106 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 145: saved images and txt files.
# Detected 6212 keypoints
# Detected 3043 keypoints
# Found 715 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 146: saved images and txt files.
# Detected 6267 keypoints
# Detected 2965 keypoints
# Found 897 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 147: saved images and txt files.
# Detected 6363 keypoints
# Detected 3041 keypoints
# Found 1569 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 148: saved images and txt files.
# Detected 7246 keypoints
# Detected 3193 keypoints
# Found 1563 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 149: saved images and txt files.
# Detected 6989 keypoints
# Detected 3143 keypoints
# Found 871 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 150: saved images and txt files.
# Detected 6467 keypoints
# Detected 2995 keypoints
# Found 399 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 151: saved images and txt files.
# Detected 5532 keypoints
# Detected 3085 keypoints
# Found 982 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 152: saved images and txt files.
# Detected 5789 keypoints
# Detected 3130 keypoints
# Found 1376 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 153: saved images and txt files.
# Detected 5895 keypoints
# Detected 2950 keypoints
# Found 1028 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 154: saved images and txt files.
# Detected 5360 keypoints
# Detected 2848 keypoints
# Found 798 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 155: saved images and txt files.
# Detected 5004 keypoints
# Detected 2561 keypoints
# Found 1117 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 156: saved images and txt files.
# Detected 4986 keypoints
# Detected 2562 keypoints
# Found 1359 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 157: saved images and txt files.
# Detected 4886 keypoints
# Detected 2552 keypoints
# Found 1295 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 158: saved images and txt files.
# Detected 4873 keypoints
# Detected 2570 keypoints
# Found 1288 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 159: saved images and txt files.
# Detected 4822 keypoints
# Detected 2605 keypoints
# Found 1202 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 160: saved images and txt files.
# Detected 4827 keypoints
# Detected 2581 keypoints
# Found 1334 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 161: saved images and txt files.
# Detected 4810 keypoints
# Detected 2637 keypoints
# Found 1152 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 162: saved images and txt files.
# Detected 4996 keypoints
# Detected 2692 keypoints
# Found 1431 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 163: saved images and txt files.
# Detected 4939 keypoints
# Detected 2721 keypoints
# Found 1261 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 164: saved images and txt files.
# Detected 4925 keypoints
# Detected 2822 keypoints
# Found 1340 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 165: saved images and txt files.
# Detected 4864 keypoints
# Detected 2799 keypoints
# Found 1434 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 166: saved images and txt files.
# Detected 4782 keypoints
# Detected 2991 keypoints
# Found 1431 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 167: saved images and txt files.
# Detected 4893 keypoints
# Detected 3034 keypoints
# Found 1350 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 168: saved images and txt files.
# Detected 5096 keypoints
# Detected 3214 keypoints
# Found 1451 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 169: saved images and txt files.
# Detected 5131 keypoints
# Detected 3279 keypoints
# Found 1383 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 170: saved images and txt files.
# Detected 5071 keypoints
# Detected 3265 keypoints
# Found 1399 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 171: saved images and txt files.
# Detected 5013 keypoints
# Detected 3404 keypoints
# Found 1199 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 172: saved images and txt files.
# Detected 4990 keypoints
# Detected 3527 keypoints
# Found 1097 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 173: saved images and txt files.
# Detected 5210 keypoints
# Detected 3464 keypoints
# Found 898 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 174: saved images and txt files.
# Detected 5542 keypoints
# Detected 3473 keypoints
# Found 1202 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 175: saved images and txt files.
# Detected 6230 keypoints
# Detected 3379 keypoints
# Found 1164 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 176: saved images and txt files.
# Detected 6308 keypoints
# Detected 3502 keypoints
# Found 1195 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 177: saved images and txt files.
# Detected 5924 keypoints
# Detected 3386 keypoints
# Found 1079 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 178: saved images and txt files.
# Detected 5893 keypoints
# Detected 3375 keypoints
# Found 1119 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 179: saved images and txt files.
# Detected 5959 keypoints
# Detected 3445 keypoints
# Found 1162 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 180: saved images and txt files.
# Detected 5683 keypoints
# Detected 3449 keypoints
# Found 1297 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 181: saved images and txt files.
# Detected 6042 keypoints
# Detected 3414 keypoints
# Found 1117 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 182: saved images and txt files.
# Detected 5995 keypoints
# Detected 3457 keypoints
# Found 1044 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 183: saved images and txt files.
# Detected 5992 keypoints
# Detected 3492 keypoints
# Found 1063 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 184: saved images and txt files.
# Detected 5966 keypoints
# Detected 3430 keypoints
# Found 544 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 185: saved images and txt files.
# Detected 6141 keypoints
# Detected 3393 keypoints
# Found 829 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 186: saved images and txt files.
# Detected 6049 keypoints
# Detected 3481 keypoints
# Found 917 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 187: saved images and txt files.
# Detected 6192 keypoints
# Detected 3412 keypoints
# Found 901 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 188: saved images and txt files.
# Detected 6232 keypoints
# Detected 3486 keypoints
# Found 936 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 189: saved images and txt files.
# Detected 6202 keypoints
# Detected 3509 keypoints
# Found 989 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 190: saved images and txt files.
# Detected 6301 keypoints
# Detected 3452 keypoints
# Found 890 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 191: saved images and txt files.
# Detected 6325 keypoints
# Detected 3437 keypoints
# Found 1126 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 192: saved images and txt files.
# Detected 6333 keypoints
# Detected 3422 keypoints
# Found 1031 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 193: saved images and txt files.
# Detected 6349 keypoints
# Detected 3437 keypoints
# Found 1131 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 194: saved images and txt files.
# Detected 6405 keypoints
# Detected 3400 keypoints
# Found 1103 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 195: saved images and txt files.
# Detected 6377 keypoints
# Detected 3436 keypoints
# Found 895 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 196: saved images and txt files.
# Detected 6583 keypoints
# Detected 3532 keypoints
# Found 1146 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 197: saved images and txt files.
# Detected 6547 keypoints
# Detected 3584 keypoints
# Found 934 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 198: saved images and txt files.
# Detected 6500 keypoints
# Detected 3734 keypoints
# Found 918 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 199: saved images and txt files.
# Detected 6470 keypoints
# Detected 3633 keypoints
# Found 764 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 200: saved images and txt files.
# Detected 6572 keypoints
# Detected 3677 keypoints
# Found 788 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 201: saved images and txt files.
# Detected 6625 keypoints
# Detected 3565 keypoints
# Found 805 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 202: saved images and txt files.
# Detected 6583 keypoints
# Detected 3502 keypoints
# Found 889 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 203: saved images and txt files.
# Detected 6433 keypoints
# Detected 3418 keypoints
# Found 829 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 204: saved images and txt files.
# Detected 6235 keypoints
# Detected 3462 keypoints
# Found 585 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 205: saved images and txt files.
# Detected 6129 keypoints
# Detected 3372 keypoints
# Found 450 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 206: saved images and txt files.
# Detected 5843 keypoints
# Detected 3414 keypoints
# Found 551 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 207: saved images and txt files.
# Detected 5900 keypoints
# Detected 3401 keypoints
# Found 591 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 208: saved images and txt files.
# Detected 5903 keypoints
# Detected 3474 keypoints
# Found 421 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 209: saved images and txt files.
# Detected 5961 keypoints
# Detected 3377 keypoints
# Found 450 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 210: saved images and txt files.
# Detected 6060 keypoints
# Detected 3315 keypoints
# Found 425 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 211: saved images and txt files.
# Detected 6126 keypoints
# Detected 3384 keypoints
# Found 268 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 212: saved images and txt files.
# Detected 6088 keypoints
# Detected 3518 keypoints
# Found 325 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 213: saved images and txt files.
# Detected 6057 keypoints
# Detected 3596 keypoints
# Found 422 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 214: saved images and txt files.
# Detected 6189 keypoints
# Detected 3564 keypoints
# Found 554 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 215: saved images and txt files.
# Detected 6170 keypoints
# Detected 3654 keypoints
# Found 514 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 216: saved images and txt files.
# Detected 6103 keypoints
# Detected 3700 keypoints
# Found 526 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 217: saved images and txt files.
# Detected 6202 keypoints
# Detected 3672 keypoints
# Found 467 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 218: saved images and txt files.
# Detected 6359 keypoints
# Detected 3574 keypoints
# Found 582 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 219: saved images and txt files.
# Detected 6259 keypoints
# Detected 3506 keypoints
# Found 667 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 220: saved images and txt files.
# Detected 6174 keypoints
# Detected 3350 keypoints
# Found 689 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 221: saved images and txt files.
# Detected 6282 keypoints
# Detected 3233 keypoints
# Found 753 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 222: saved images and txt files.
# Detected 6227 keypoints
# Detected 3121 keypoints
# Found 731 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 223: saved images and txt files.
# Detected 6158 keypoints
# Detected 3108 keypoints
# Found 864 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 224: saved images and txt files.
# Detected 6207 keypoints
# Detected 3036 keypoints
# Found 851 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 225: saved images and txt files.
# Detected 6210 keypoints
# Detected 2977 keypoints
# Found 872 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 226: saved images and txt files.
# Detected 5802 keypoints
# Detected 2951 keypoints
# Found 750 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 227: saved images and txt files.
# Detected 5751 keypoints
# Detected 2954 keypoints
# Found 633 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 228: saved images and txt files.
# Detected 5674 keypoints
# Detected 3058 keypoints
# Found 612 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 229: saved images and txt files.
# Detected 5542 keypoints
# Detected 3056 keypoints
# Found 579 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 230: saved images and txt files.
# Detected 5450 keypoints
# Detected 3008 keypoints
# Found 782 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 231: saved images and txt files.
# Detected 5345 keypoints
# Detected 2903 keypoints
# Found 821 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 232: saved images and txt files.
# Detected 5316 keypoints
# Detected 2961 keypoints
# Found 811 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 233: saved images and txt files.
# Detected 5265 keypoints
# Detected 2885 keypoints
# Found 827 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 234: saved images and txt files.
# Detected 5566 keypoints
# Detected 2843 keypoints
# Found 798 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 235: saved images and txt files.
# Detected 5443 keypoints
# Detected 2827 keypoints
# Found 754 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 236: saved images and txt files.
# Detected 5632 keypoints
# Detected 2724 keypoints
# Found 814 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 237: saved images and txt files.
# Detected 5379 keypoints
# Detected 2577 keypoints
# Found 692 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 238: saved images and txt files.
# Detected 5324 keypoints
# Detected 2477 keypoints
# Found 509 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 239: saved images and txt files.
# Detected 5096 keypoints
# Detected 2413 keypoints
# Found 501 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 240: saved images and txt files.
# Detected 4643 keypoints
# Detected 2357 keypoints
# Found 323 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 241: saved images and txt files.
# Detected 4597 keypoints
# Detected 2412 keypoints
# Found 323 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 242: saved images and txt files.
# Detected 4444 keypoints
# Detected 2422 keypoints
# Found 293 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 243: saved images and txt files.
# Detected 4029 keypoints
# Detected 2429 keypoints
# Found 539 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 244: saved images and txt files.
# Detected 4393 keypoints
# Detected 2408 keypoints
# Found 391 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 245: saved images and txt files.
# Detected 4492 keypoints
# Detected 2413 keypoints
# Found 280 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 246: saved images and txt files.
# Detected 4495 keypoints
# Detected 2397 keypoints
# Found 359 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 247: saved images and txt files.
# Detected 4481 keypoints
# Detected 2415 keypoints
# Found 210 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 248: saved images and txt files.
# Detected 4543 keypoints
# Detected 2444 keypoints
# Found 215 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 249: saved images and txt files.
# Detected 4686 keypoints
# Detected 2442 keypoints
# Found 246 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 250: saved images and txt files.
# Detected 4834 keypoints
# Detected 2425 keypoints
# Found 197 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 251: saved images and txt files.
# Detected 4822 keypoints
# Detected 2435 keypoints
# Found 219 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 252: saved images and txt files.
# Detected 4914 keypoints
# Detected 2372 keypoints
# Found 242 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 253: saved images and txt files.
# Detected 4908 keypoints
# Detected 2328 keypoints
# Found 256 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 254: saved images and txt files.
# Detected 4965 keypoints
# Detected 2387 keypoints
# Found 191 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 255: saved images and txt files.
# Detected 4818 keypoints
# Detected 2382 keypoints
# Found 216 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 256: saved images and txt files.
# Detected 4988 keypoints
# Detected 2356 keypoints
# Found 185 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 257: saved images and txt files.
# Detected 5064 keypoints
# Detected 2399 keypoints
# Found 267 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 258: saved images and txt files.
# Detected 4967 keypoints
# Detected 2436 keypoints
# Found 198 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 259: saved images and txt files.
# Detected 4966 keypoints
# Detected 2437 keypoints
# Found 248 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 260: saved images and txt files.
# Detected 4891 keypoints
# Detected 2437 keypoints
# Found 236 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 261: saved images and txt files.
# Detected 4748 keypoints
# Detected 2425 keypoints
# Found 315 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 262: saved images and txt files.
# Detected 4461 keypoints
# Detected 2375 keypoints
# Found 272 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 263: saved images and txt files.
# Detected 4178 keypoints
# Detected 2341 keypoints
# Found 277 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 264: saved images and txt files.
# Detected 4048 keypoints
# Detected 2158 keypoints
# Found 203 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 265: saved images and txt files.
# Detected 3848 keypoints
# Detected 1985 keypoints
# Found 218 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 266: saved images and txt files.
# Detected 3589 keypoints
# Detected 1980 keypoints
# Found 344 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 267: saved images and txt files.
# Detected 3532 keypoints
# Detected 1969 keypoints
# Found 381 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 268: saved images and txt files.
# Detected 3370 keypoints
# Detected 1846 keypoints
# Found 623 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 269: saved images and txt files.
# Detected 3056 keypoints
# Detected 1729 keypoints
# Found 537 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 270: saved images and txt files.
# Detected 3044 keypoints
# Detected 1724 keypoints
# Found 542 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 271: saved images and txt files.
# Detected 3025 keypoints
# Detected 1722 keypoints
# Found 402 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 272: saved images and txt files.
# Detected 2863 keypoints
# Detected 1649 keypoints
# Found 395 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 273: saved images and txt files.
# Detected 2905 keypoints
# Detected 1710 keypoints
# Found 450 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 274: saved images and txt files.
# Detected 2839 keypoints
# Detected 1733 keypoints
# Found 336 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 275: saved images and txt files.
# Detected 2784 keypoints
# Detected 1684 keypoints
# Found 366 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 276: saved images and txt files.
# Detected 2857 keypoints
# Detected 1655 keypoints
# Found 327 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 277: saved images and txt files.
# Detected 2757 keypoints
# Detected 1694 keypoints
# Found 285 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 278: saved images and txt files.
# Detected 2752 keypoints
# Detected 1660 keypoints
# Found 286 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 279: saved images and txt files.
# Detected 2634 keypoints
# Detected 1596 keypoints
# Found 490 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 280: saved images and txt files.
# Detected 2613 keypoints
# Detected 1670 keypoints
# Found 372 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 281: saved images and txt files.
# Detected 2761 keypoints
# Detected 1644 keypoints
# Found 376 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 282: saved images and txt files.
# Detected 2781 keypoints
# Detected 1642 keypoints
# Found 213 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 283: saved images and txt files.
# Detected 2835 keypoints
# Detected 1641 keypoints
# Found 162 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 284: saved images and txt files.
# Detected 2792 keypoints
# Detected 1581 keypoints
# Found 154 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 285: saved images and txt files.
# Detected 2683 keypoints
# Detected 1568 keypoints
# Found 86 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 286: saved images and txt files.
# Detected 2593 keypoints
# Detected 1551 keypoints
# Found 96 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 287: saved images and txt files.
# Detected 2608 keypoints
# Detected 1505 keypoints
# Found 104 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 288: saved images and txt files.
# Detected 2575 keypoints
# Detected 1510 keypoints
# Found 130 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 289: saved images and txt files.
# Detected 2556 keypoints
# Detected 1428 keypoints
# Found 202 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 290: saved images and txt files.
# Detected 2642 keypoints
# Detected 1459 keypoints
# Found 165 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 291: saved images and txt files.
# Detected 2685 keypoints
# Detected 1447 keypoints
# Found 142 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 292: saved images and txt files.
# Detected 2766 keypoints
# Detected 1431 keypoints
# Found 104 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 293: saved images and txt files.
# Detected 2837 keypoints
# Detected 1421 keypoints
# Found 152 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 294: saved images and txt files.
# Detected 2706 keypoints
# Detected 1412 keypoints
# Found 164 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 295: saved images and txt files.
# Detected 2599 keypoints
# Detected 1355 keypoints
# Found 144 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 296: saved images and txt files.
# Detected 2537 keypoints
# Detected 1409 keypoints
# Found 65 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 297: saved images and txt files.
# Detected 2589 keypoints
# Detected 1402 keypoints
# Found 36 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 298: saved images and txt files.
# Detected 2566 keypoints
# Detected 1465 keypoints
# Found 31 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 299: saved images and txt files.
# Detected 2605 keypoints
# Detected 1542 keypoints
# Found 72 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 300: saved images and txt files.
# Detected 2635 keypoints
# Detected 1515 keypoints
# Found 160 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 301: saved images and txt files.
# Detected 2686 keypoints
# Detected 1484 keypoints
# Found 302 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 302: saved images and txt files.
# Detected 2720 keypoints
# Detected 1460 keypoints
# Found 420 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 303: saved images and txt files.
# Detected 2681 keypoints
# Detected 1454 keypoints
# Found 409 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 304: saved images and txt files.
# Detected 2748 keypoints
# Detected 1474 keypoints
# Found 355 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 305: saved images and txt files.
# Detected 2722 keypoints
# Detected 1509 keypoints
# Found 313 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 306: saved images and txt files.
# Detected 2724 keypoints
# Detected 1500 keypoints
# Found 355 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 307: saved images and txt files.
# Detected 2758 keypoints
# Detected 1558 keypoints
# Found 388 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 308: saved images and txt files.
# Detected 2519 keypoints
# Detected 1515 keypoints
# Found 176 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 309: saved images and txt files.
# Detected 2637 keypoints
# Detected 1503 keypoints
# Found 58 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 310: saved images and txt files.
# Detected 2644 keypoints
# Detected 1565 keypoints
# Found 543 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 311: saved images and txt files.
# Detected 2666 keypoints
# Detected 1517 keypoints
# Found 158 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 312: saved images and txt files.
# Detected 2689 keypoints
# Detected 1490 keypoints
# Found 277 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 313: saved images and txt files.
# Detected 2701 keypoints
# Detected 1480 keypoints
# Found 270 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 314: saved images and txt files.
# Detected 2683 keypoints
# Detected 1506 keypoints
# Found 293 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 315: saved images and txt files.
# Detected 2719 keypoints
# Detected 1598 keypoints
# Found 69 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 316: saved images and txt files.
# Detected 2713 keypoints
# Detected 1609 keypoints
# Found 18 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 317: saved images and txt files.
# Detected 2560 keypoints
# Detected 1703 keypoints
# Found 62 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 318: saved images and txt files.
# Detected 2003 keypoints
# Detected 1806 keypoints
# Found 537 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 319: saved images and txt files.
# Detected 2153 keypoints
# Detected 1863 keypoints
# Found 583 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 320: saved images and txt files.
# Detected 2716 keypoints
# Detected 1790 keypoints
# Found 266 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 321: saved images and txt files.
# Detected 2939 keypoints
# Detected 1589 keypoints
# Found 263 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 322: saved images and txt files.
# Detected 2644 keypoints
# Detected 1534 keypoints
# Found 46 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 323: saved images and txt files.
# Detected 2685 keypoints
# Detected 1541 keypoints
# Found 29 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 324: saved images and txt files.
# Detected 2754 keypoints
# Detected 1497 keypoints
# Found 170 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 325: saved images and txt files.
# Detected 2714 keypoints
# Detected 1504 keypoints
# Found 231 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 326: saved images and txt files.
# Detected 2691 keypoints
# Detected 1520 keypoints
# Found 324 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 327: saved images and txt files.
# Detected 2761 keypoints
# Detected 1510 keypoints
# ...
# Detected 2767 keypoints
# Detected 1593 keypoints
# Found 118 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 342: saved images and txt files.
# Detected 2805 keypoints
# Detected 1597 keypoints
# Found 87 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 343: saved images and txt files.
# Detected 2773 keypoints
# Detected 1589 keypoints
# Found 124 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 344: saved images and txt files.
# Detected 2766 keypoints
# Detected 1578 keypoints
# Found 184 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 345: saved images and txt files.
# Detected 2827 keypoints
# Detected 1516 keypoints
# Found 257 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 346: saved images and txt files.
# Detected 2805 keypoints
# Detected 1559 keypoints
# Found 315 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 347: saved images and txt files.
# Detected 2810 keypoints
# Detected 1546 keypoints
# Found 270 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 348: saved images and txt files.
# Detected 2795 keypoints
# Detected 1481 keypoints
# Found 184 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 349: saved images and txt files.
# Detected 2796 keypoints
# Detected 1512 keypoints
# Found 185 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 350: saved images and txt files.
# Detected 2784 keypoints
# Detected 1493 keypoints
# Found 138 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 351: saved images and txt files.
# Detected 2785 keypoints
# Detected 1535 keypoints
# Found 137 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 352: saved images and txt files.
# Detected 2811 keypoints
# Detected 1547 keypoints
# Found 73 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 353: saved images and txt files.
# Detected 2737 keypoints
# Detected 1541 keypoints
# Found 137 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 354: saved images and txt files.
# Detected 2744 keypoints
# Detected 1692 keypoints
# Found 263 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 355: saved images and txt files.
# Detected 3007 keypoints
# Detected 1791 keypoints
# Found 21 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 356: saved images and txt files.
# Detected 2962 keypoints
# Detected 1731 keypoints
# Found 172 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 357: saved images and txt files.
# Detected 2865 keypoints
# Detected 1601 keypoints
# Found 421 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 358: saved images and txt files.
# Detected 2812 keypoints
# Detected 1556 keypoints
# Found 471 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 359: saved images and txt files.
# Detected 2779 keypoints
# Detected 1499 keypoints
# Found 463 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 360: saved images and txt files.
# Detected 2741 keypoints
# Detected 1491 keypoints
# Found 300 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 361: saved images and txt files.
# Detected 2752 keypoints
# Detected 1510 keypoints
# Found 341 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 362: saved images and txt files.
# Detected 2777 keypoints
# Detected 1535 keypoints
# Found 444 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 363: saved images and txt files.
# Detected 2765 keypoints
# Detected 1595 keypoints
# Found 540 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 364: saved images and txt files.
# Detected 2794 keypoints
# Detected 1576 keypoints
# Found 561 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 365: saved images and txt files.
# Detected 2862 keypoints
# Detected 1503 keypoints
# Found 662 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 366: saved images and txt files.
# Detected 2731 keypoints
# Detected 1560 keypoints
# Found 722 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 367: saved images and txt files.
# Detected 2655 keypoints
# Detected 1641 keypoints
# Found 389 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 368: saved images and txt files.
# Detected 2592 keypoints
# Detected 1803 keypoints
# Found 610 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 369: saved images and txt files.
# Detected 2775 keypoints
# Detected 1718 keypoints
# Found 696 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 370: saved images and txt files.
# Detected 2753 keypoints
# Detected 1875 keypoints
# Found 536 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 371: saved images and txt files.
# Detected 2923 keypoints
# Detected 1921 keypoints
# Found 440 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 372: saved images and txt files.
# Detected 3050 keypoints
# Detected 1930 keypoints
# Found 588 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 373: saved images and txt files.
# Detected 3204 keypoints
# Detected 2161 keypoints
# Found 596 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 374: saved images and txt files.
# Detected 3342 keypoints
# Detected 2312 keypoints
# Found 627 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 375: saved images and txt files.
# Detected 3468 keypoints
# Detected 2331 keypoints
# Found 540 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 376: saved images and txt files.
# Detected 3545 keypoints
# Detected 2353 keypoints
# Found 494 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 377: saved images and txt files.
# Detected 3522 keypoints
# Detected 2441 keypoints
# Found 402 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 378: saved images and txt files.
# Detected 3596 keypoints
# Detected 2501 keypoints
# Found 496 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 379: saved images and txt files.
# Detected 3632 keypoints
# Detected 2556 keypoints
# Found 381 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 380: saved images and txt files.
# Detected 3686 keypoints
# Detected 2656 keypoints
# Found 381 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 381: saved images and txt files.
# Detected 3786 keypoints
# Detected 2587 keypoints
# Found 467 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 382: saved images and txt files.
# Detected 3829 keypoints
# Detected 2497 keypoints
# Found 554 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 383: saved images and txt files.
# Detected 3648 keypoints
# Detected 2420 keypoints
# Found 437 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 384: saved images and txt files.
# Detected 3726 keypoints
# Detected 2567 keypoints
# Found 606 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 385: saved images and txt files.
# Detected 3672 keypoints
# Detected 2832 keypoints
# Found 809 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 386: saved images and txt files.
# Detected 3765 keypoints
# Detected 2763 keypoints
# Found 694 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 387: saved images and txt files.
# Detected 3865 keypoints
# Detected 2472 keypoints
# Found 724 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 388: saved images and txt files.
# Detected 3932 keypoints
# Detected 2606 keypoints
# Found 818 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 389: saved images and txt files.
# Detected 3994 keypoints
# Detected 2756 keypoints
# Found 712 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 390: saved images and txt files.
# Detected 3979 keypoints
# Detected 2715 keypoints
# Found 739 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 391: saved images and txt files.
# Detected 3838 keypoints
# Detected 2586 keypoints
# Found 952 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 392: saved images and txt files.
# Detected 4095 keypoints
# Detected 2668 keypoints
# Found 942 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 393: saved images and txt files.
# Detected 3984 keypoints
# Detected 2687 keypoints
# Found 1204 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 394: saved images and txt files.
# Detected 3819 keypoints
# Detected 2546 keypoints
# Found 1314 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 395: saved images and txt files.
# Detected 4014 keypoints
# Detected 2811 keypoints
# Found 1302 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 396: saved images and txt files.
# Detected 4056 keypoints
# Detected 2878 keypoints
# Found 1257 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 397: saved images and txt files.
# Detected 4211 keypoints
# Detected 2921 keypoints
# Found 1352 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 398: saved images and txt files.
# Detected 4119 keypoints
# Detected 2869 keypoints
# Found 1374 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 399: saved images and txt files.
# Detected 4353 keypoints
# Detected 2928 keypoints
# Found 1234 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 400: saved images and txt files.
# Detected 4246 keypoints
# Detected 3005 keypoints
# Found 1163 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 401: saved images and txt files.
# Detected 4176 keypoints
# Detected 3041 keypoints
# Found 1222 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 402: saved images and txt files.
# Detected 4473 keypoints
# Detected 3263 keypoints
# Found 1081 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 403: saved images and txt files.
# Detected 4557 keypoints
# Detected 3329 keypoints
# Found 792 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 404: saved images and txt files.
# Detected 4810 keypoints
# Detected 3519 keypoints
# Found 866 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 405: saved images and txt files.
# Detected 5133 keypoints
# Detected 3679 keypoints
# Found 646 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 406: saved images and txt files.
# Detected 5467 keypoints
# Detected 3737 keypoints
# Found 722 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 407: saved images and txt files.
# Detected 5627 keypoints
# Detected 3810 keypoints
# Found 663 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 408: saved images and txt files.
# Detected 5674 keypoints
# Detected 3848 keypoints
# Found 838 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 409: saved images and txt files.
# Detected 5405 keypoints
# Detected 3291 keypoints
# Found 846 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 410: saved images and txt files.
# Detected 4636 keypoints
# Detected 2895 keypoints
# Found 909 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 411: saved images and txt files.
# Detected 3998 keypoints
# Detected 2831 keypoints
# Found 1054 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 412: saved images and txt files.
# Detected 3953 keypoints
# Detected 2631 keypoints
# Found 1031 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 413: saved images and txt files.
# Detected 3507 keypoints
# Detected 2411 keypoints
# Found 687 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 414: saved images and txt files.
# Detected 3141 keypoints
# Detected 2275 keypoints
# Found 701 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 415: saved images and txt files.
# Detected 3184 keypoints
# Detected 2102 keypoints
# Found 784 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 416: saved images and txt files.
# Detected 3064 keypoints
# Detected 2141 keypoints
# Found 764 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 417: saved images and txt files.
# Detected 3221 keypoints
# Detected 2163 keypoints
# Found 755 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 418: saved images and txt files.
# Detected 3139 keypoints
# Detected 2100 keypoints
# Found 764 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 419: saved images and txt files.
# Detected 2998 keypoints
# Detected 2285 keypoints
# Found 800 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 420: saved images and txt files.
# Detected 8235 keypoints
# Detected 4463 keypoints
# Found 2248 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 421: saved images and txt files.
# Detected 8199 keypoints
# Detected 4451 keypoints
# Found 2235 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 422: saved images and txt files.
# Detected 8096 keypoints
# Detected 4466 keypoints
# Found 2206 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 423: saved images and txt files.
# Detected 8119 keypoints
# Detected 4484 keypoints
# Found 2320 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 424: saved images and txt files.
# Detected 8091 keypoints
# Detected 4539 keypoints
# Found 2143 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 425: saved images and txt files.
# Detected 8023 keypoints
# Detected 4786 keypoints
# Found 2170 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 426: saved images and txt files.
# Detected 7715 keypoints
# Detected 4668 keypoints
# Found 1975 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 427: saved images and txt files.
# Detected 7673 keypoints
# Detected 4439 keypoints
# Found 2073 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 428: saved images and txt files.
# Detected 7499 keypoints
# Detected 4352 keypoints
# Found 2148 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 429: saved images and txt files.
# Detected 7401 keypoints
# Detected 4250 keypoints
# Found 2210 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 430: saved images and txt files.
# Detected 7386 keypoints
# Detected 4582 keypoints
# Found 2336 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 431: saved images and txt files.
# Detected 7261 keypoints
# Detected 4623 keypoints
# Found 1920 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 432: saved images and txt files.
# Detected 7162 keypoints
# Detected 4462 keypoints
# Found 1638 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 433: saved images and txt files.
# Detected 6900 keypoints
# Detected 4360 keypoints
# Found 1746 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 434: saved images and txt files.
# Detected 6959 keypoints
# Detected 4549 keypoints
# Found 1825 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 435: saved images and txt files.
# Detected 6822 keypoints
# Detected 4045 keypoints
# Found 2132 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 436: saved images and txt files.
# Detected 6801 keypoints
# Detected 3735 keypoints
# Found 2263 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 437: saved images and txt files.
# Detected 6435 keypoints
# Detected 3638 keypoints
# Found 2364 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 438: saved images and txt files.
# Detected 6493 keypoints
# Detected 3646 keypoints
# Found 2493 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 439: saved images and txt files.
# Detected 6692 keypoints
# Detected 3605 keypoints
# Found 2601 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 440: saved images and txt files.
# Detected 6547 keypoints
# Detected 3579 keypoints
# Found 2525 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 441: saved images and txt files.
# Detected 6686 keypoints
# Detected 3712 keypoints
# Found 2545 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 442: saved images and txt files.
# Detected 6636 keypoints
# Detected 3727 keypoints
# Found 2541 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 443: saved images and txt files.
# Detected 6686 keypoints
# Detected 3818 keypoints
# Found 2636 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 444: saved images and txt files.
# Detected 6560 keypoints
# Detected 3943 keypoints
# Found 2605 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 445: saved images and txt files.
# Detected 6627 keypoints
# Detected 3838 keypoints
# Found 2519 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 446: saved images and txt files.
# Detected 6509 keypoints
# Detected 3815 keypoints
# Found 2521 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 447: saved images and txt files.
# Detected 6608 keypoints
# Detected 3849 keypoints
# Found 2601 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 448: saved images and txt files.
# Detected 6802 keypoints
# Detected 3857 keypoints
# Found 2719 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 449: saved images and txt files.
# Detected 6754 keypoints
# Detected 3970 keypoints
# Found 2469 valid matches
# (1200, 1920)
# (1200, 1920)
# Processed pair 450: saved images and txt files.

# %% [markdown]
# ## Now Rectification

# %%
import numpy as np
# import cv2 as cv
import math
import sys

#TransformCorners: transforms corner points by a Homography
#
#H: Homography
#(WIDTH,HEIGHT): image sizes
#
#Return: 3x4 matrix with the transformed corners. Points are given in homogeneous coordinates.
def TransformCorners(H,WIDTH,HEIGHT):
    pts=np.ones((3,4))
#Corners:
    pts[0,0]=0;
    pts[1,0]=0;

    pts[0,1]=WIDTH;
    pts[1,1]=0;

    pts[0,2]=0;
    pts[1,2]=HEIGHT;

    pts[0,3]=WIDTH;
    pts[1,3]=HEIGHT;
#Transformation
    pts=H1@pts
    return pts

#H1: homography for first image
#(WIDTH1,HEIGHT1): size of first image
#
#H2: homography for first image
#(WIDTH2,HEIGHT2): size of first image
#(EXPECTED_WIDTH,EXPECTED_HEIGHT): expected sizef of the resulting rectified images
#
#Return: Correction homography


def FinalScaleOffset(H1,WIDTH1,HEIGHT1,H2,WIDTH2,HEIGHT2,EXPECTED_WIDTH,EXPECTED_HEIGHT):

    ptsIm=np.ones((8,2))

    pts1Hom=TransformCorners(H1,WIDTH1,HEIGHT1)
    pts2Hom=TransformCorners(H2,WIDTH2,HEIGHT2)

    print("pts1Hom:",pts1Hom)
    print("pts2Hom:",pts2Hom)

    # print(pts1Hom)

    for idx in range(0,4):
        pt1=pts1Hom[0:2,idx]/pts1Hom[2,idx]
        pt2=pts2Hom[0:2,idx]/pts2Hom[2,idx]

        ptsIm[idx,:]=pt1
        ptsIm[idx+4,:]=pt1

    minPts=ptsIm.min(0)
    maxPts=ptsIm.max(0)

    print("Pts:",ptsIm)

    print("minPts",minPts)
    print("maxPts",maxPts)

    alphaW=EXPECTED_WIDTH/(maxPts[0]-minPts[0])
    betaW=-1.0*alphaW*minPts[0]

    alphaH=EXPECTED_HEIGHT/(maxPts[1]-minPts[1])
    betaH=-1.0*alphaH*minPts[1]

    Corr=np.eye((3))
    Corr[0,0]=alphaW
    Corr[1,1]=alphaH
    Corr[0,2]=betaW
    Corr[1,2]=betaH

    return Corr


#Estimate the verticalScaleand Offset
#Fmod
#pts1Hom,pts2Hom: Points after transformation in homogeneous coordinates
#Return: Desired transformation
#
#The scale and offset is given as y1=alpha*y2+beta2
#

def EstimateVerticalOffsetAndScale(Fmod,pts1Hom,pts2Hom):

#Number of points
    NUMP=pts1Hom.shape[1]

#Each point gives an equation for alpha and beta
    Cfs=np.zeros((NUMP,2))
    right=np.zeros((NUMP,1))

    for idx in range(0,NUMP):
#Get original homogeneous coordinates:
        p1Hom=pts1Hom[:,idx]
        p2Hom=pts2Hom[:,idx]
#y2:
        Cfs[idx,0]=p2Hom[1]/p2Hom[2]  # coordinate x
        Cfs[idx,1]=1.0

        right[idx,0]=p1Hom[1]/p1Hom[2]

#Over-determined inhomogeneous linear system of equations
    params=np.linalg.inv(Cfs.transpose()@Cfs)@Cfs.transpose()@right
    alpha=params[0]
    beta=params[1]


#First transformation is the identity, second one is the copmputed scale/offset
    H1=np.eye((3))
    H2=np.eye((3))

    H2[1,1]=alpha
    H2[1,2]=beta

    return H1,H2


#This method is the essence of rectification
#It moves the epipole to the infinity
#
#Input:
#
#epipole: computed epipole. It is input even if it can be computed as the kernel of F.
#F: fundamental matrix
#
#Return:
#Resulting homography

def EstimateRectifyingHomography(epipole,F):

#In the first step, the vertical coordinate of the epipole should be moved to y=0
    tform1=np.eye((3))
    tform1[1,2]=-epipole[1]

    #Tform 2 is the projective warp
    tform2=np.eye((3))
    tform2[2,0]=-1.0/epipole[0];

    H=tform2@tform1

    return H

# %% [markdown]
# ## For single image

# %%
# fileName1=sys.argv[1]
# fileName2=sys.argv[2]

# img1 = cv.imread(fileName1)  #queryimage # left image
# img2 = cv.imread(fileName1) #trainimage # right image

# img1 = cv2.imread('a.png')  #queryimage # left image
# img2 = cv2.imread('b.png') #trainimage # right image

img1 = cv2.imread('../../dataset_budapest/elte_car_stereo/dev0_70_520/Dev0_Image_w1920_h1200_fn457.jpg', cv2.IMREAD_GRAYSCALE)  #queryimage # left image #, cv.IMREAD_GRAYSCALE
img2 = cv2.imread('../../dataset_budapest/elte_car_stereo/dev1_70_520/Dev1_Image_w1920_h1200_fn457.jpg', cv2.IMREAD_GRAYSCALE)

#Copy original images. It will be saved later

origImg1=img1.copy()
origImg2=img2.copy()



#Image sizes:
WIDTH1=img1.shape[1]
HEIGHT1=img1.shape[0]

WIDTH2=img2.shape[1]
HEIGHT2=img2.shape[0]


#White:
color=np.ones(3)


#Load fundamental matrix and matched (inlier) feature point:
F=np.loadtxt("rect_results/F_RANSAC.mat")
pts1=np.loadtxt("rect_results/pts1.mat")
pts2=np.loadtxt("rect_results/pts2.mat")


#Compute epipoles

u,s,vt= np.linalg.svd(F)

#Left and right kernels give epipoles
epipole1=vt[2,:]
epipole2=u[:,2]

#Homogeneous division required!
epipole1=epipole1/epipole1[2]
epipole2=epipole2/epipole2[2]


#For debug:
print("Epipole1:",epipole1[0:2])
print("Epipole2:",epipole2[0:2])



##Parameter to visualize epipoles. Distance between drawn lines
SKIP=10

#Number of drawn epilines
NUM=int(math.floor(HEIGHT1/SKIP))



#Take and draw epipolar lines in the second image
for idx in range(0,NUM):
    ptHom=np.ones(3)
#Center of width
    ptHom[0]=int(WIDTH1/2)
#Uniform sampling:
    ptHom[1]=idx*SKIP

#Epipolar line in the second image
    line2=F@ptHom

#Get endpoints of line in the screen.
    x0,y0 = map(int, [0, -line2[2]/line2[1] ])
    x1,y1 = map(int, [WIDTH2, -(line2[2]+line2[0]*WIDTH2)/line2[1] ])
#Draw it
    img2 = cv2.line(img2, (x0,y0), (x1,y1), color,1)



#Take and draw epipolar lines in the first image image

NUM=int(math.floor(HEIGHT2/SKIP))

for idx in range(0,NUM):
    ptHom=np.ones(3)
    ptHom[1]=idx*SKIP
    ptHom[0]=int(WIDTH2/2)

#F.transpose() gives the inverz of the fundamental matrix!
    line1=F.transpose()@ptHom

    x0,y0 = map(int, [0, -line1[2]/line1[1] ])
    x1,y1 = map(int, [WIDTH1, -(line1[2]+line1[0]*WIDTH1)/line1[1] ])
    img1 = cv2.line(img1, (x0,y0), (x1,y1), color,1)




#Write images for debgging purposes

cv2.imwrite("rect_results/res1.png",img1)
cv2.imwrite("rect_results/res2.png",img2)


#Move epipoles to the infinity:
H1=EstimateRectifyingHomography(epipole1,F)
H2=EstimateRectifyingHomography(epipole2,F.transpose())


tmp1 = cv2.warpPerspective(origImg1, H1,(WIDTH1,HEIGHT1))
tmp2 = cv2.warpPerspective(origImg2, H2,(WIDTH2,HEIGHT2))

cv2.imwrite("rect_results/tmp1.png",tmp1)
cv2.imwrite("rect_results/tmp2.png",tmp2)


#Modified fundamental matrix
Fmod=np.linalg.inv(H2.transpose())@F@np.linalg.inv(H1)



#Transform the point coordinates by the obtrained homography

#Number of points
NUMP=pts1.shape[0]

#Point should be considered in its homogeneous form
pts1Hom=np.ones((NUMP,3))
pts2Hom=np.ones((NUMP,3))




for idx in range(0,NUMP):
    pts1Hom[idx,0]=pts1[idx,0]
    pts1Hom[idx,1]=pts1[idx,1]

    pts2Hom[idx,0]=pts2[idx,0]
    pts2Hom[idx,1]=pts2[idx,1]



pts1Hom=H1@(pts1Hom.transpose())
pts2Hom=H2@(pts2Hom.transpose())


#Make horizontal epipolar lines parallel by estimating a scale and an offset
H1second,H2second=EstimateVerticalOffsetAndScale(Fmod,pts1Hom,pts2Hom)

H1=H1second@H1
H2=H2second@H2



#Finally, move the image to the center and resize the images

EXPECTED_WIDTH=960
EXPECTED_HEIGHT=600 #600


Corr= FinalScaleOffset(H1,WIDTH1,HEIGHT1,H2,WIDTH2,HEIGHT2,EXPECTED_WIDTH,EXPECTED_HEIGHT)


H1=Corr@H1
H2=Corr@H2


## Calculations for doffs
# camera_matrix = np.array([   # Budapest dataset
#     [1250, 0, 960],
#     [0, 1250, 600],
#     [0, 0, 1]
# ])

camera_matrix = np.array([   # Budapest dataset
    [625, 0, 480],
    [0, 625, 300],
    [0, 0, 1]
])
p1 = np.array([camera_matrix[0, 2], camera_matrix[1, 2], 1])  # [960, 600, 1]
p2 = np.array([camera_matrix[0, 2], camera_matrix[1, 2], 1])

p1_rect = H1 @ p1
p2_rect = H2 @ p2

# Normalize the homogeneous coordinates
p1_rect = p1_rect / p1_rect[2]
p2_rect = p2_rect / p2_rect[2]

# Calculate disparity offset (doffs)
doffs = p2_rect[0] - p1_rect[0]
print("Disparity offset (doffs):", doffs)


#Finally, draw image for debugging purposes:


transformed1 = cv2.warpPerspective(img1, H1,(EXPECTED_WIDTH,EXPECTED_HEIGHT))
transformed2 = cv2.warpPerspective(img2, H2,(EXPECTED_WIDTH,EXPECTED_HEIGHT))

cv2.imwrite("rect_results/transformed1.png",transformed1)
cv2.imwrite("rect_results/transformed2.png",transformed2)

#Rectify original images.

result1 = cv2.warpPerspective(origImg1, H1,(EXPECTED_WIDTH,EXPECTED_HEIGHT))
result2 = cv2.warpPerspective(origImg2, H2,(EXPECTED_WIDTH,EXPECTED_HEIGHT))

cv2.imwrite("rect_results/final1.png",result1)
cv2.imwrite("rect_results/final2.png",result2)

#Concatenate resulting images:
final=cv2.hconcat([result1,result2])
cv2.imwrite("rect_results/finalRectified.png",final)

final=cv2.hconcat([origImg1,origImg2])
cv2.imwrite("rect_results/origRectified.png",final)
# Out:
# Epipole1: [6971.1238279   546.33332895]
# Epipole2: [8069.84973282  322.84901382]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.46333329e+02 -5.46333329e+02  6.53666671e+02  6.53666671e+02]
#  [ 1.00000000e+00  7.24578124e-01  1.00000000e+00  7.24578124e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.46333329e+02 -5.46333329e+02  6.53666671e+02  6.53666671e+02]
#  [ 1.00000000e+00  7.24578124e-01  1.00000000e+00  7.24578124e-01]]
# Pts: [[   0.         -546.33332895]
#  [2649.81778424 -754.00196415]
#  [   0.          653.66667105]
#  [2649.81778424  902.134151  ]
#  [   0.         -546.33332895]
#  [2649.81778424 -754.00196415]
#  [   0.          653.66667105]
#  [2649.81778424  902.134151  ]]
# minPts [   0.         -754.00196415]
# maxPts [2649.81778424  902.134151  ]
# Disparity offset (doffs): -1.8615469315089683
# True

# %% [markdown]
# ## For all images

# %%
import cv2
import numpy as np
import math
import glob
import os

# # Define your camera matrix (example for the Budapest dataset)
camera_matrix_01 = np.array([   # elte_car_stereo, cam0
    [1.1049e+03,-263.4241,1.1561e+03],
    [0,1.1799e+03,235.7677],
    [0, 0, 1]
])

camera_matrix_02 = np.array([   # elte_car_stereo, cam1 
    [4.9384e+03,-363.6950,1.1743e+03],
    [0,4.5852e+03,809.9989],
    [0, 0, 1]
])
# camera_matrix = np.array([   # Budapest dataset
#     [625, 0, 480],
#     [0, 625, 300],
#     [0, 0, 1]
# ])
# camera_matrix_01 =	np.array([[1.2799e+03,0,1.0148e+03] , [0,1.2841e+03,573.2751] , [0,0,1]])

# camera_matrix_02 = 	np.array([[1.2706e+03,0,961.2221] , [0,1.2739e+03,611.5167] , [0,0,1]])


camera_matrix_01_r = camera_matrix_01 / 2
camera_matrix_02_r = camera_matrix_02 / 2

# Directories for left/right images (update extensions if needed)
left_img_files = sorted(glob.glob('../../dataset_budapest/elte_car_stereo/dev0_70_520/*.jpg'))
right_img_files = sorted(glob.glob('../../dataset_budapest/elte_car_stereo/dev1_70_520/*.jpg'))

# Directory where the F and pts files are saved
results_dir = "rect_results"
results_dir_l = "rect_results/dev0"
results_dir_r = "rect_results/dev1"
doffs_array = []
# Get the number of pairs (assuming the ordering of left/right is matching)
num_pairs = min(len(left_img_files), len(right_img_files))

for i in range(num_pairs):
    print(f"Processing pair {i}")
    # Read left and right images
    img1 = cv2.imread(left_img_files[i])
    img2 = cv2.imread(right_img_files[i])
    if img1 is None or img2 is None:
        print(f"Error reading images for pair {i}")
        continue

    # Save original images for later warping
    origImg1 = img1.copy()
    origImg2 = img2.copy()

    # Image sizes
    WIDTH1, HEIGHT1 = img1.shape[1], img1.shape[0]
    WIDTH2, HEIGHT2 = img2.shape[1], img2.shape[0]

    # White color for drawing (you can adjust as needed)
    color = np.ones(3)  # This creates a [1,1,1] vector (if needed, multiply by 255)

    # Read the fundamental matrix and inlier feature points for this pair
    F_path = os.path.join(results_dir, f"F_RANSAC_pair_{i}.txt")
    pts1_path = os.path.join(results_dir, f"pts1_pair_{i}.txt")
    pts2_path = os.path.join(results_dir, f"pts2_pair_{i}.txt")
    try:
        F = np.loadtxt(F_path)
        pts1 = np.loadtxt(pts1_path)
        pts2 = np.loadtxt(pts2_path)
    except Exception as e:
        print(f"Error loading F/pts for pair {i}: {e}")
        continue

    # --- Compute epipoles ---
    u, s, vt = np.linalg.svd(F)
    epipole1 = vt[2, :]
    epipole2 = u[:, 2]
    epipole1 = epipole1 / epipole1[2]
    epipole2 = epipole2 / epipole2[2]
    print(f"Pair {i} - Epipole1: {epipole1[0:2]}, Epipole2: {epipole2[0:2]}")

    # --- Draw epipolar lines on the images for debugging ---
    SKIP = 10  # vertical spacing between sampled lines

    # Draw epipolar lines in the second image based on points in the first image
    NUM = int(math.floor(HEIGHT1 / SKIP))
    for idx in range(NUM):
        ptHom = np.ones(3)
        ptHom[0] = int(WIDTH1 / 2)
        ptHom[1] = idx * SKIP
        line2 = F @ ptHom
        if line2[1] != 0:
            x0, y0 = 0, int(-line2[2] / line2[1])
            x1, y1 = WIDTH2, int(-(line2[2] + line2[0] * WIDTH2) / line2[1])
            img2 = cv2.line(img2, (x0, y0), (x1, y1), color.tolist(), 1)

    NUM = int(math.floor(HEIGHT2 / SKIP))
    for idx in range(NUM):
        ptHom = np.ones(3)
        ptHom[1] = idx * SKIP
        ptHom[0] = int(WIDTH2 / 2)
        line1 = F.transpose() @ ptHom
        if line1[1] != 0:
            x0, y0 = 0, int(-line1[2] / line1[1])
            x1, y1 = WIDTH1, int(-(line1[2] + line1[0] * WIDTH1) / line1[1])
            img1 = cv2.line(img1, (x0, y0), (x1, y1), color.tolist(), 1)

    # Save intermediate images with epipolar lines
    # cv2.imwrite(os.path.join(results_dir, f"res1_pair_{i}.png"), img1)
    # cv2.imwrite(os.path.join(results_dir, f"res2_pair_{i}.png"), img2)

    # --- Rectification Steps ---
    # Compute rectifying homographies that move the epipoles to infinity
    H1 = EstimateRectifyingHomography(epipole1, F)
    H2 = EstimateRectifyingHomography(epipole2, F.transpose())

    tmp1 = cv2.warpPerspective(origImg1, H1, (WIDTH1, HEIGHT1))
    tmp2 = cv2.warpPerspective(origImg2, H2, (WIDTH2, HEIGHT2))
    # cv2.imwrite(os.path.join(results_dir, f"tmp1_pair_{i}.png"), tmp1)
    # cv2.imwrite(os.path.join(results_dir, f"tmp2_pair_{i}.png"), tmp2)

    # Modified fundamental matrix
    Fmod = np.linalg.inv(H2.transpose()) @ F @ np.linalg.inv(H1)

    # Transform point coordinates to the rectified space (homogeneous coordinates)
    NUMP = pts1.shape[0]
    pts1Hom = np.hstack([pts1, np.ones((NUMP, 1))]).T
    pts2Hom = np.hstack([pts2, np.ones((NUMP, 1))]).T
    pts1Hom = H1 @ pts1Hom
    pts2Hom = H2 @ pts2Hom

    # Adjust vertical offset and scale so that the epipolar lines are horizontal
    H1second, H2second = EstimateVerticalOffsetAndScale(Fmod, pts1Hom, pts2Hom)
    H1 = H1second @ H1
    H2 = H2second @ H2

    # Center and resize images to the expected dimensions
    EXPECTED_WIDTH = 960
    EXPECTED_HEIGHT = 600
    Corr = FinalScaleOffset(H1, WIDTH1, HEIGHT1, H2, WIDTH2, HEIGHT2, EXPECTED_WIDTH, EXPECTED_HEIGHT)
    H1 = Corr @ H1
    H2 = Corr @ H2

    # --- Compute disparity offset (doffs) for the whole images ---
    # p1 and p2 are the principal points (center) in the original images (homogeneous coordinates)
    p1 = np.array([camera_matrix_01_r[0, 2], camera_matrix_01_r[1, 2], 1])
    p2 = np.array([camera_matrix_02_r[0, 2], camera_matrix_02_r[1, 2], 1])
    p1_rect = H1 @ p1
    p2_rect = H2 @ p2
    p1_rect = p1_rect / p1_rect[2]
    p2_rect = p2_rect / p2_rect[2]
    doffs = p2_rect[0] - p1_rect[0]
    doffs_array.append(doffs)
    print(f"Pair {i} - Disparity offset (doffs): {doffs}")

    # --- Warp the images using the computed homographies ---
    transformed1 = cv2.warpPerspective(img1, H1, (EXPECTED_WIDTH, EXPECTED_HEIGHT))
    transformed2 = cv2.warpPerspective(img2, H2, (EXPECTED_WIDTH, EXPECTED_HEIGHT))
    # cv2.imwrite(os.path.join(results_dir, f"transformed1_pair_{i}.png"), transformed1)
    # cv2.imwrite(os.path.join(results_dir, f"transformed2_pair_{i}.png"), transformed2)

    result1 = cv2.warpPerspective(origImg1, H1, (EXPECTED_WIDTH, EXPECTED_HEIGHT))
    result2 = cv2.warpPerspective(origImg2, H2, (EXPECTED_WIDTH, EXPECTED_HEIGHT))
    cv2.imwrite(os.path.join(results_dir_l, f"final1_pair_{i}.png"), result1)
    cv2.imwrite(os.path.join(results_dir_r, f"final2_pair_{i}.png"), result2)

    # --- Save concatenated rectified images for comparison ---
    final_rectified = cv2.hconcat([result1, result2])
    # cv2.imwrite(os.path.join(results_dir, f"finalRectified_pair_{i}.png"), final_rectified)
    orig_concat = cv2.hconcat([origImg1, origImg2])
    # cv2.imwrite(os.path.join(results_dir, f"origRectified_pair_{i}.png"), orig_concat)

    print(f"Finished processing pair {i}\n")
# Out:
# Processing pair 0
# Pair 0 - Epipole1: [2451.01660143  460.95621421], Epipole2: [2422.20248469  421.25459023]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4.60956214e+02 -4.60956214e+02  7.39043786e+02  7.39043786e+02]
#  [ 1.00000000e+00  2.16651573e-01  1.00000000e+00  2.16651573e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4.60956214e+02 -4.60956214e+02  7.39043786e+02  7.39043786e+02]
#  [ 1.00000000e+00  2.16651573e-01  1.00000000e+00  2.16651573e-01]]
# Pts: [[    0.          -460.95621421]
#  [ 8862.15583855 -2127.63844014]
#  [    0.           739.04378579]
#  [ 8862.15583855  3411.20895895]
#  [    0.          -460.95621421]
#  [ 8862.15583855 -2127.63844014]
#  [    0.           739.04378579]
#  [ 8862.15583855  3411.20895895]]
# minPts [    0.         -2127.63844014]
# maxPts [8862.15583855 3411.20895895]
# Pair 0 - Disparity offset (doffs): 2.010980797052852
# Finished processing pair 0
#
# Processing pair 1
# Pair 1 - Epipole1: [2869.33367865  530.77438054], Epipole2: [2864.93949053  465.07986585]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.30774381e+02 -5.30774381e+02  6.69225619e+02  6.69225619e+02]
#  [ 1.00000000e+00  3.30855099e-01  1.00000000e+00  3.30855099e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.30774381e+02 -5.30774381e+02  6.69225619e+02  6.69225619e+02]
#  [ 1.00000000e+00  3.30855099e-01  1.00000000e+00  3.30855099e-01]]
# Pts: [[    0.          -530.77438054]
#  [ 5803.14465493 -1604.25026533]
#  [    0.           669.22561946]
#  [ 5803.14465493  2022.715144  ]
#  [    0.          -530.77438054]
#  [ 5803.14465493 -1604.25026533]
#  [    0.           669.22561946]
#  [ 5803.14465493  2022.715144  ]]
# minPts [    0.         -1604.25026533]
# maxPts [5803.14465493 2022.715144  ]
# Pair 1 - Disparity offset (doffs): 2.418391174964171
# Finished processing pair 1
#
# Processing pair 2
# Pair 2 - Epipole1: [2378.45818801  565.7249346 ], Epipole2: [2345.29491083  533.66628765]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.65724935e+02 -5.65724935e+02  6.34275065e+02  6.34275065e+02]
#  [ 1.00000000e+00  1.92754361e-01  1.00000000e+00  1.92754361e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.65724935e+02 -5.65724935e+02  6.34275065e+02  6.34275065e+02]
#  [ 1.00000000e+00  1.92754361e-01  1.00000000e+00  1.92754361e-01]]
# Pts: [[    0.          -565.7249346 ]
#  [ 9960.86413201 -2934.95271338]
#  [    0.           634.2750654 ]
#  [ 9960.86413201  3290.58736913]
#  [    0.          -565.7249346 ]
#  [ 9960.86413201 -2934.95271338]
#  [    0.           634.2750654 ]
#  [ 9960.86413201  3290.58736913]]
# minPts [    0.         -2934.95271338]
# maxPts [9960.86413201 3290.58736913]
# Pair 2 - Disparity offset (doffs): 1.8882546214225755
# Finished processing pair 2
#
# Processing pair 3
# Pair 3 - Epipole1: [3095.12099778  464.20762704], Epipole2: [3331.70320988  389.02839432]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4.64207627e+02 -4.64207627e+02  7.35792373e+02  7.35792373e+02]
#  [ 1.00000000e+00  3.79668840e-01  1.00000000e+00  3.79668840e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4.64207627e+02 -4.64207627e+02  7.35792373e+02  7.35792373e+02]
#  [ 1.00000000e+00  3.79668840e-01  1.00000000e+00  3.79668840e-01]]
# Pts: [[    0.          -464.20762704]
#  [ 5057.03865981 -1222.66453965]
#  [    0.           735.79237296]
#  [ 5057.03865981  1937.98462273]
#  [    0.          -464.20762704]
#  [ 5057.03865981 -1222.66453965]
#  [    0.           735.79237296]
#  [ 5057.03865981  1937.98462273]]
# minPts [    0.         -1222.66453965]
# maxPts [5057.03865981 1937.98462273]
# Pair 3 - Disparity offset (doffs): 0.372152207714322
# Finished processing pair 3
#
# Processing pair 4
# Pair 4 - Epipole1: [1982.25372624  594.64690478], Epipole2: [1875.72901241  569.80758405]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.94646905e+02 -5.94646905e+02  6.05353095e+02  6.05353095e+02]
#  [ 1.00000000e+00  3.14055287e-02  1.00000000e+00  3.14055287e-02]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.94646905e+02 -5.94646905e+02  6.05353095e+02  6.05353095e+02]
#  [ 1.00000000e+00  3.14055287e-02  1.00000000e+00  3.14055287e-02]]
# Pts: [[     0.           -594.64690478]
#  [ 61135.7324948  -18934.46567698]
#  [     0.            605.35309522]
#  [ 61135.7324948   19275.36713228]
#  [     0.           -594.64690478]
#  [ 61135.7324948  -18934.46567698]
#  [     0.            605.35309522]
#  [ 61135.7324948   19275.36713228]]
# minPts [     0.         -18934.46567698]
# maxPts [61135.7324948  19275.36713228]
# Pair 4 - Disparity offset (doffs): 0.6073951415002892
# Finished processing pair 4
#
# Processing pair 5
# Pair 5 - Epipole1: [2086.62609022  508.14198102], Epipole2: [1996.65381127  477.70689931]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.08141981e+02 -5.08141981e+02  6.91858019e+02  6.91858019e+02]
#  [ 1.00000000e+00  7.98543117e-02  1.00000000e+00  7.98543117e-02]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.08141981e+02 -5.08141981e+02  6.91858019e+02  6.91858019e+02]
#  [ 1.00000000e+00  7.98543117e-02  1.00000000e+00  7.98543117e-02]]
# Pts: [[    0.          -508.14198102]
#  [24043.78622762 -6363.36310675]
#  [    0.           691.85801898]
#  [24043.78622762  8664.00328551]
#  [    0.          -508.14198102]
#  [24043.78622762 -6363.36310675]
#  [    0.           691.85801898]
#  [24043.78622762  8664.00328551]]
# minPts [    0.         -6363.36310675]
# maxPts [24043.78622762  8664.00328551]
# Pair 5 - Disparity offset (doffs): 1.285308244379042
# Finished processing pair 5
#
# Processing pair 6
# Pair 6 - Epipole1: [2074.41326841  586.38575573], Epipole2: [2016.05747633  560.0219402 ]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.86385756e+02 -5.86385756e+02  6.13614244e+02  6.13614244e+02]
#  [ 1.00000000e+00  7.44370810e-02  1.00000000e+00  7.44370810e-02]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.86385756e+02 -5.86385756e+02  6.13614244e+02  6.13614244e+02]
#  [ 1.00000000e+00  7.44370810e-02  1.00000000e+00  7.44370810e-02]]
# Pts: [[    0.          -586.38575573]
#  [25793.59608338 -7877.60277729]
#  [    0.           613.61424427]
#  [25793.59608338  8243.39477483]
#  [    0.          -586.38575573]
#  [25793.59608338 -7877.60277729]
#  [    0.           613.61424427]
#  [25793.59608338  8243.39477483]]
# minPts [    0.         -7877.60277729]
# maxPts [25793.59608338  8243.39477483]
# Pair 6 - Disparity offset (doffs): 1.0072169308056296
# Finished processing pair 6
#
# Processing pair 7
# Pair 7 - Epipole1: [2491.3868121   615.54098986], Epipole2: [2483.66947879  578.78385108]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.15540990e+02 -6.15540990e+02  5.84459010e+02  5.84459010e+02]
#  [ 1.00000000e+00  2.29344881e-01  1.00000000e+00  2.29344881e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.15540990e+02 -6.15540990e+02  5.84459010e+02  5.84459010e+02]
#  [ 1.00000000e+00  2.29344881e-01  1.00000000e+00  2.29344881e-01]]
# Pts: [[    0.          -615.54098986]
#  [ 8371.67148053 -2683.90986974]
#  [    0.           584.45901014]
#  [ 8371.67148053  2548.38480558]
#  [    0.          -615.54098986]
#  [ 8371.67148053 -2683.90986974]
#  [    0.           584.45901014]
#  [ 8371.67148053  2548.38480558]]
# minPts [    0.         -2683.90986974]
# maxPts [8371.67148053 2548.38480558]
# Pair 7 - Disparity offset (doffs): 1.8622272657986088
# Finished processing pair 7
#
# Processing pair 8
# Pair 8 - Epipole1: [2042.90947624  611.97829171], Epipole2: [1987.0583762   589.69595846]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.11978292e+02 -6.11978292e+02  5.88021708e+02  5.88021708e+02]
#  [ 1.00000000e+00  6.01639366e-02  1.00000000e+00  6.01639366e-02]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.11978292e+02 -6.11978292e+02  5.88021708e+02  5.88021708e+02]
#  [ 1.00000000e+00  6.01639366e-02  1.00000000e+00  6.01639366e-02]]
# Pts: [[     0.           -611.97829171]
#  [ 31912.80537843 -10171.8458954 ]
#  [     0.            588.02170829]
#  [ 31912.80537843   9773.65746612]
#  [     0.           -611.97829171]
#  [ 31912.80537843 -10171.8458954 ]
#  [     0.            588.02170829]
#  [ 31912.80537843   9773.65746612]]
# minPts [     0.        -10171.8458954]
# maxPts [31912.80537843  9773.65746612]
# Pair 8 - Disparity offset (doffs): 0.819962597711136
# Finished processing pair 8
#
# Processing pair 9
# Pair 9 - Epipole1: [2230.69767279  563.71987891], Epipole2: [2189.43024546  533.79277949]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.63719879e+02 -5.63719879e+02  6.36280121e+02  6.36280121e+02]
#  [ 1.00000000e+00  1.39282735e-01  1.00000000e+00  1.39282735e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.63719879e+02 -5.63719879e+02  6.36280121e+02  6.36280121e+02]
#  [ 1.00000000e+00  1.39282735e-01  1.00000000e+00  1.39282735e-01]]
# Pts: [[    0.          -563.71987891]
#  [13784.91024177 -4047.30621476]
#  [    0.           636.28012109]
#  [13784.91024177  4568.26268635]
#  [    0.          -563.71987891]
#  [13784.91024177 -4047.30621476]
#  [    0.           636.28012109]
#  [13784.91024177  4568.26268635]]
# minPts [    0.         -4047.30621476]
# maxPts [13784.91024177  4568.26268635]
# Pair 9 - Disparity offset (doffs): 1.53721625565165
# Finished processing pair 9
#
# Processing pair 10
# Pair 10 - Epipole1: [2906.2029505   458.06681665], Epipole2: [3053.76211651  384.38902288]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4.58066817e+02 -4.58066817e+02  7.41933183e+02  7.41933183e+02]
#  [ 1.00000000e+00  3.39344143e-01  1.00000000e+00  3.39344143e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4.58066817e+02 -4.58066817e+02  7.41933183e+02  7.41933183e+02]
#  [ 1.00000000e+00  3.39344143e-01  1.00000000e+00  3.39344143e-01]]
# Pts: [[    0.          -458.06681665]
#  [ 5657.97299851 -1349.85920839]
#  [    0.           741.93318335]
#  [ 5657.97299851  2186.37391567]
#  [    0.          -458.06681665]
#  [ 5657.97299851 -1349.85920839]
#  [    0.           741.93318335]
#  [ 5657.97299851  2186.37391567]]
# minPts [    0.         -1349.85920839]
# maxPts [5657.97299851 2186.37391567]
# Pair 10 - Disparity offset (doffs): 0.906448338043603
# Finished processing pair 10
#
# Processing pair 11
# Pair 11 - Epipole1: [2478.50342152  485.19799005], Epipole2: [2460.08504125  443.60107223]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-4
-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.34283021e+02 -6.34283021e+02  5.65716979e+02  5.65716979e+02]
#  [ 1.00000000e+00  1.73409131e-01  1.00000000e+00  1.73409131e-01]]
# Pts: [[    0.          -634.28302052]
#  [11072.08129193 -3657.72560691]
#  [    0.           565.71697948]
#  [11072.08129193  3262.32520055]
#  [    0.          -634.28302052]
#  [11072.08129193 -3657.72560691]
#  [    0.           565.71697948]
#  [11072.08129193  3262.32520055]]
# minPts [    0.         -3657.72560691]
# maxPts [11072.08129193  3262.32520055]
# Pair 45 - Disparity offset (doffs): 1.9670116343835105
# Finished processing pair 45
#
# Processing pair 46
# Pair 46 - Epipole1: [2392.11824019  583.18854816], Epipole2: [2378.32248763  542.30118317]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.83188548e+02 -5.83188548e+02  6.16811452e+02  6.16811452e+02]
#  [ 1.00000000e+00  1.97364090e-01  1.00000000e+00  1.97364090e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.83188548e+02 -5.83188548e+02  6.16811452e+02  6.16811452e+02]
#  [ 1.00000000e+00  1.97364090e-01  1.00000000e+00  1.97364090e-01]]
# Pts: [[    0.          -583.18854816]
#  [ 9728.21346467 -2954.88681597]
#  [    0.           616.81145184]
#  [ 9728.21346467  3125.24659945]
#  [    0.          -583.18854816]
#  [ 9728.21346467 -2954.88681597]
#  [    0.           616.81145184]
#  [ 9728.21346467  3125.24659945]]
# minPts [    0.         -2954.88681597]
# maxPts [9728.21346467 3125.24659945]
# Pair 46 - Disparity offset (doffs): 1.71452585649007
# Finished processing pair 46
#
# Processing pair 47
# Pair 47 - Epipole1: [2527.27223005  579.28421209], Epipole2: [2511.88951893  531.13656343]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.79284212e+02 -5.79284212e+02  6.20715788e+02  6.20715788e+02]
#  [ 1.00000000e+00  2.40287620e-01  1.00000000e+00  2.40287620e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.79284212e+02 -5.79284212e+02  6.20715788e+02  6.20715788e+02]
#  [ 1.00000000e+00  2.40287620e-01  1.00000000e+00  2.40287620e-01]]
# Pts: [[    0.          -579.28421209]
#  [ 7990.42413207 -2410.79507689]
#  [    0.           620.71578791]
#  [ 7990.42413207  2583.22000565]
#  [    0.          -579.28421209]
#  [ 7990.42413207 -2410.79507689]
#  [    0.           620.71578791]
#  [ 7990.42413207  2583.22000565]]
# minPts [    0.         -2410.79507689]
# maxPts [7990.42413207 2583.22000565]
# Pair 47 - Disparity offset (doffs): 2.0171506790099585
# Finished processing pair 47
#
# Processing pair 48
# Pair 48 - Epipole1: [2003.66664571  667.20822169], Epipole2: [1946.65067561  640.49906452]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.67208222e+02 -6.67208222e+02  5.32791778e+02  5.32791778e+02]
#  [ 1.00000000e+00  4.17567692e-02  1.00000000e+00  4.17567692e-02]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.67208222e+02 -6.67208222e+02  5.32791778e+02  5.32791778e+02]
#  [ 1.00000000e+00  4.17567692e-02  1.00000000e+00  4.17567692e-02]]
# Pts: [[     0.           -667.20822169]
#  [ 45980.56880719 -15978.4445554 ]
#  [     0.            532.79177831]
#  [ 45980.56880719  12759.4109491 ]
#  [     0.           -667.20822169]
#  [ 45980.56880719 -15978.4445554 ]
#  [     0.            532.79177831]
#  [ 45980.56880719  12759.4109491 ]]
# minPts [     0.        -15978.4445554]
# maxPts [45980.56880719 12759.4109491 ]
# Pair 48 - Disparity offset (doffs): 0.5908189055405764
# Finished processing pair 48
#
# Processing pair 49
# Pair 49 - Epipole1: [2330.81485658  486.27679259], Epipole2: [2258.71534563  442.63570178]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [
-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.52638977e+02 -6.52638977e+02  5.47361023e+02  5.47361023e+02]
#  [ 1.00000000e+00  2.72125250e-01  1.00000000e+00  2.72125250e-01]]
# Pts: [[    0.          -652.63897677]
#  [ 7055.57459574 -2398.30363785]
#  [    0.           547.36102323]
#  [ 7055.57459574  2011.43048449]
#  [    0.          -652.63897677]
#  [ 7055.57459574 -2398.30363785]
#  [    0.           547.36102323]
#  [ 7055.57459574  2011.43048449]]
# minPts [    0.         -2398.30363785]
# maxPts [7055.57459574 2011.43048449]
# Pair 437 - Disparity offset (doffs): -2.3994399923493575
# Finished processing pair 437
#
# Processing pair 438
# Pair 438 - Epipole1: [2322.89903004  569.71634215], Epipole2: [2556.02233952  527.97433902]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.69716342e+02 -5.69716342e+02  6.30283658e+02  6.30283658e+02]
#  [ 1.00000000e+00  1.73446639e-01  1.00000000e+00  1.73446639e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.69716342e+02 -5.69716342e+02  6.30283658e+02  6.30283658e+02]
#  [ 1.00000000e+00  1.73446639e-01  1.00000000e+00  1.73446639e-01]]
# Pts: [[    0.          -569.71634215]
#  [11069.68695675 -3284.67789673]
#  [    0.           630.28365785]
#  [11069.68695675  3633.87645124]
#  [    0.          -569.71634215]
#  [11069.68695675 -3284.67789673]
#  [    0.           630.28365785]
#  [11069.68695675  3633.87645124]]
# minPts [    0.         -3284.67789673]
# maxPts [11069.68695675  3633.87645124]
# Pair 438 - Disparity offset (doffs): -0.6334348110476924
# Finished processing pair 438
#
# Processing pair 439
# Pair 439 - Epipole1: [2390.52526996  716.31278541], Epipole2: [2557.23418364  703.26841908]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-7.16312785e+02 -7.16312785e+02  4.83687215e+02  4.83687215e+02]
#  [ 1.00000000e+00  1.96829239e-01  1.00000000e+00  1.96829239e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-7.16312785e+02 -7.16312785e+02  4.83687215e+02  4.83687215e+02]
#  [ 1.00000000e+00  1.96829239e-01  1.00000000e+00  1.96829239e-01]]
# Pts: [[    0.          -716.31278541]
#  [ 9754.64828637 -3639.26004409]
#  [    0.           483.68721459]
#  [ 9754.64828637  2457.39513489]
#  [    0.          -716.31278541]
#  [ 9754.64828637 -3639.26004409]
#  [    0.           483.68721459]
#  [ 9754.64828637  2457.39513489]]
# minPts [    0.         -3639.26004409]
# maxPts [9754.64828637 2457.39513489]
# Pair 439 - Disparity offset (doffs): -0.026234092551504773
# Finished processing pair 439
#
# Processing pair 440
# Pair 440 - Epipole1: [2371.22136983  547.31260037], Epipole2: [2464.90557077  506.50382276]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.47312600e+02 -5.47312600e+02  6.52687400e+02  6.52687400e+02]
#  [ 1.00000000e+00  1.90290698e-01  1.00000000e+00  1.90290698e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.47312600e+02 -5.47312600e+02  6.52687400e+02  6.52687400e+02]
#  [ 1.00000000e+00  1.90290698e-01  1.00000000e+00  1.90290698e-01]]
# Pts: [[    0.          -547.31260037]
#  [10089.82582501 -2876.1920883 ]
#  [    0.           652.68739963]
#  [10089.82582501  3429.94905233]
#  [    0.          -547.31260037]
#  [10089.82582501 -2876.1920883 ]
#  [    0.           652.68739963]
#  [10089.82582501  3429.94905233]]
# minPts [    0.        -2876.1920883]
# maxPts [10089.82582501  3429.94905233]
# Pair 440 - Disparity offset (doffs): 0.6044578168662298
# Finished processing pair 440
#
# Processing pair 441
# Pair 441 - Epipole1: [2931.20901749  579.21787122], Epipole2: [3220.13837051  525.18905806]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5

# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.57123442e+02 -5.57123442e+02  6.42876558e+02  6.42876558e+02]
#  [ 1.00000000e+00  2.99826318e-01  1.00000000e+00  2.99826318e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-5.57123442e+02 -5.57123442e+02  6.42876558e+02  6.42876558e+02]
#  [ 1.00000000e+00  2.99826318e-01  1.00000000e+00  2.99826318e-01]]
# Pts: [[    0.          -557.12344189]
#  [ 6403.70736231 -1858.15389924]
#  [    0.           642.87655811]
#  [ 6403.70736231  2144.16320221]
#  [    0.          -557.12344189]
#  [ 6403.70736231 -1858.15389924]
#  [    0.           642.87655811]
#  [ 6403.70736231  2144.16320221]]
# minPts [    0.         -1858.15389924]
# maxPts [6403.70736231 2144.16320221]
# Pair 448 - Disparity offset (doffs): 1.0768786849788938
# Finished processing pair 448
#
# Processing pair 449
# Pair 449 - Epipole1: [2246.46497698  600.09534474], Epipole2: [2226.3470499   567.28170185]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.00095345e+02 -6.00095345e+02  5.99904655e+02  5.99904655e+02]
#  [ 1.00000000e+00  1.45323867e-01  1.00000000e+00  1.45323867e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.00095345e+02 -6.00095345e+02  5.99904655e+02  5.99904655e+02]
#  [ 1.00000000e+00  1.45323867e-01  1.00000000e+00  1.45323867e-01]]
# Pts: [[    0.          -600.09534474]
#  [13211.86975623 -4129.36538336]
#  [    0.           599.90465526]
#  [13211.86975623  4128.05321429]
#  [    0.          -600.09534474]
#  [13211.86975623 -4129.36538336]
#  [    0.           599.90465526]
#  [13211.86975623  4128.05321429]]
# minPts [    0.         -4129.36538336]
# maxPts [13211.86975623  4128.05321429]
# Pair 449 - Disparity offset (doffs): 1.3906342342806326
# Finished processing pair 449
#
# Processing pair 450
# Pair 450 - Epipole1: [2954.22176815  603.10784119], Epipole2: [3068.94791452  557.24565898]
# pts1Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.03107841e+02 -6.03107841e+02  5.96892159e+02  5.96892159e+02]
#  [ 1.00000000e+00  3.50082644e-01  1.00000000e+00  3.50082644e-01]]
# pts2Hom: [[ 0.00000000e+00  1.92000000e+03  0.00000000e+00  1.92000000e+03]
#  [-6.03107841e+02 -6.03107841e+02  5.96892159e+02  5.96892159e+02]
#  [ 1.00000000e+00  3.50082644e-01  1.00000000e+00  3.50082644e-01]]
# Pts: [[    0.          -603.10784119]
#  [ 5484.41927015 -1722.75847197]
#  [    0.           596.89215881]
#  [ 5484.41927015  1705.00357188]
#  [    0.          -603.10784119]
#  [ 5484.41927015 -1722.75847197]
#  [    0.           596.89215881]
#  [ 5484.41927015  1705.00357188]]
# minPts [    0.         -1722.75847197]
# maxPts [5484.41927015 1705.00357188]
# Pair 450 - Disparity offset (doffs): 1.2931212177589515
# Finished processing pair 450

# %%
doffs_array
# Out:
# [np.float64(1.535659444085752),
#  np.float64(-1.682309343633051),
#  np.float64(1.1645537178629297),
#  np.float64(0.2409340709010337),
#  np.float64(-0.14552526246578168),
#  np.float64(-2.2216238552981338),
#  np.float64(-2.465884939152005),
#  np.float64(3.8000305947960555),
#  np.float64(-6.228136560543646),
#  np.float64(1.8736960794601316),
#  np.float64(-1.8019498716385556),
#  np.float64(1.947205814744791),
#  np.float64(-0.4538525623633234),
#  np.float64(1.814480744768332),
#  np.float64(-2.4135909339816237),
#  np.float64(0.2705802586710604),
#  np.float64(-2.1639273960876153),
#  np.float64(-0.18955568576967607),
#  np.float64(0.748117524584103),
#  np.float64(-2.752369824814565),
#  np.float64(-0.32108800031068085),
#  np.float64(-2.4588212724078176),
#  np.float64(0.11657716315664857)]

# %%
global_doff = np.median(doffs_array)
print("Global disparity offset (doff):", global_doff)
# Out:
# Global disparity offset (doff): 0.37672697470911487

# %%
import numpy as np

# Camera Matrix for Camera 1 (in pixels)
K_left = np.array([[6.3995000e+02, 0.0000000e+00, 5.0740000e+02],
       [0.0000000e+00, 6.4205000e+02, 2.8663755e+02],
       [0.0000000e+00, 0.0000000e+00, 5.0000000e-01]], dtype=np.float32)

# Translation vector for Camera 2 (in millimeters)
t_right_mm = np.array([-369.2437,0.4530,-11.3379])  # in millimeters

# Image Size (width x height)
image_width = 960  # image width in pixels
image_height = 600  # image height in pixels

# Convert the translation vector from millimeters to pixels
focal_length_x = K_left[0, 0]  # Focal length in x (pixels)
focal_length_y = K_left[1, 1]  # Focal length in y (pixels)

# Convert the translation vector to pixels
t_right_pixels = t_right_mm * np.array([focal_length_x / image_width, focal_length_y / image_height, 1])

# Output the converted translation vector in pixels
print("Translation Vector in Pixels:")
print(t_right_pixels)
# Out:
# Translation Vector in Pixels:
# [-246.14323845    0.48474772  -11.3379    ]

# %%
camera_matrix_01 =	np.array([[1.2799e+03,0,1.0148e+03] , [0,1.2841e+03,573.2751] , [0,0,1]])


camera_matrix_01_r = camera_matrix_01 / 2
camera_matrix_01_r
# Out:
# array([[6.3995000e+02, 0.0000000e+00, 5.0740000e+02],
#        [0.0000000e+00, 6.4205000e+02, 2.8663755e+02],
#        [0.0000000e+00, 0.0000000e+00, 5.0000000e-01]])

# %% [markdown]
# ## To rectify using openCV

# %%
import cv2
import numpy as np

# ---------------------------
# Calibration parameters
# ---------------------------

# Intrinsics for cam0 (left camera)
K_left = np.array([[1.1495e+03,0,952.4011],
                   [0,1.1448e+03,606.7985],
                   [0, 0,   1]], dtype=np.float64)

# Distortion for cam0 (left camera); MATLAB provided 2 radial coefficients and zero tangential distortion.
D_left = np.array([-0.0496,0.0361, 0, 0], dtype=np.float64)

D_right = np.array([-0.0264,0.0423, 0, 0], dtype=np.float64)
# Intrinsics for cam1 (right camera)
K_right = np.array([[1.1793e+03,0,874.7151],
                    [0,1.1727e+03,630.6559],
                    [0, 0,     1]], dtype=np.float64)

# Distortion for cam1 (right camera)
# D_71ght =np.665ay([-0.0367, 0.0265, 0, 0], dtype=np.float6# Image size in pixels (width, height)
image_size = (1920, 1200)

# Extrinsic parameters from PoseCamera2 (transformation from left to right)
R = np.array([[0.9995,0.0291,-0.0144],
              [-0.0292,0.9995,-0.0076],
              [0.0142,0.0080,0.9999]], dtype=np.float64)

T = np.array([-1.0096e+03,8.3554,78.8978], dtype=np.float64)  # in millimeters

# ---------------------------
# Read Stereo Images
# ---------------------------
img_left  = cv2.imread('../../dataset_budapest/elte_car_stereo/dev0_70_520/Dev0_Image_w1920_h1200_fn457.jpg', cv2.IMREAD_GRAYSCALE)  #queryimage # left image #, cv.IMREAD_GRAYSCALE
img_right = cv2.imread('../../dataset_budapest/elte_car_stereo/dev1_70_520/Dev1_Image_w1920_h1200_fn457.jpg', cv2.IMREAD_GRAYSCALE)


# ---------------------------
# Stereo Rectification
# ---------------------------

# The flags parameter cv2.CALIB_ZERO_DISPARITY makes the principal points of the rectified images aligned.
# alpha = -1 means that no pixels are lost (and the ROI will be computed automatically).
R1, R2, P1, P2, Q, roi1, roi2 = cv2.stereoRectify(K_left, D_left, K_right, D_right,
                                                  image_size, R, T, flags=cv2.CALIB_ZERO_DISPARITY, alpha=-1)

# Compute the undistort and rectify maps for both images.
map1_x, map1_y = cv2.initUndistortRectifyMap(K_left, D_left, R1, P1, image_size, cv2.CV_32FC1)
map2_x, map2_y = cv2.initUndistortRectifyMap(K_right, D_right, R2, P2, image_size, cv2.CV_32FC1)

# Remap the images to get rectified versions.
rectified_left = cv2.remap(img_left, map1_x, map1_y, cv2.INTER_LINEAR)
rectified_right = cv2.remap(img_right, map2_x, map2_y, cv2.INTER_LINEAR)

# ---------------------------
# Visualize the Rectified Pair
# ---------------------------
# Stack the images horizontally for visualization.
combined_rectified = np.hstack((rectified_left, rectified_right))

# Optionally, save the rectified images.
cv2.imwrite("rectified_left.png", rectified_left)
cv2.imwrite("rectified_right.png", rectified_right)

cv2.imwrite("combined.png", combined_rectified)

print("Projection Matrix P1:")
print(P1)
print("\nProjection Matrix P2:")
print(P2)

# Compute doffs as the difference between the x-coordinate of the principal points in P2 and P1
doffs = P2[0, 2] - P1[0, 2]
print("Disparity offset (doffs):", doffs)
# Out:
# Projection Matrix P1:
# [[1.15875000e+03 0.00000000e+00 1.08403688e+03 0.00000000e+00]
#  [0.00000000e+00 1.15875000e+03 6.17181320e+02 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
# Projection Matrix P2:
# [[ 1.15875000e+03  0.00000000e+00  1.08403688e+03 -1.17348074e+06]
#  [ 0.00000000e+00  1.15875000e+03  6.17181320e+02  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00]]
# Disparity offset (doffs): 0.0

# %% [markdown]
# # using same rect params for all imgs

# %%
import os, glob
import numpy as np
import cv2

# ---------------------------
# 1) Camera parameters (your values)
# ---------------------------
K_left = np.array([[1.1495e+03, 0,          952.4011],
                   [0,          1.1448e+03, 606.7985],
                   [0,          0,          1]], dtype=np.float64)

D_left = np.array([-0.0496, 0.0361, 0, 0], dtype=np.float64)

K_right = np.array([[1.1793e+03, 0,          874.7151],
                    [0,          1.1727e+03, 630.6559],
                    [0,          0,          1]], dtype=np.float64)

D_right = np.array([-0.0264, 0.0423, 0, 0], dtype=np.float64)

R = np.array([[ 0.9995,  0.0291, -0.0144],
              [-0.0292,  0.9995, -0.0076],
              [ 0.0142,  0.0080,  0.9999]], dtype=np.float64)

T = np.array([-1.0096e+03, 8.3554, 78.8978], dtype=np.float64)

image_size = (1920, 1200)  # (w, h)

# ---------------------------
# 2) Compute rectification once
# ---------------------------
R1, R2, P1, P2, Q, roi1, roi2 = cv2.stereoRectify(
    K_left, D_left, K_right, D_right, image_size, R, T,
    flags=cv2.CALIB_ZERO_DISPARITY, alpha=-1
)

map1_x, map1_y = cv2.initUndistortRectifyMap(K_left,  D_left,  R1, P1, image_size, cv2.CV_32FC1)
map2_x, map2_y = cv2.initUndistortRectifyMap(K_right, D_right, R2, P2, image_size, cv2.CV_32FC1)

print("P1:\n", P1, "\n\nP2:\n", P2)

# ---------------------------
# 3) Batch rectify helpers
# ---------------------------
def ensure_dir(p):
    os.makedirs(p, exist_ok=True)

def list_images(folder):
    exts = ("*.png", "*.jpg", "*.jpeg", "*.bmp", "*.tif", "*.tiff")
    files = []
    for e in exts:
        files.extend(glob.glob(os.path.join(folder, e)))
    files.sort()
    return files

def rectify_folder(input_dir, output_dir, mapx, mapy, resize_to=(960, 600)):
    ensure_dir(output_dir)
    files = list_images(input_dir)
    print(f"[{input_dir}] -> [{output_dir}]  |  {len(files)} images")

    for idx, f in enumerate(files, 1):
        img = cv2.imread(f, cv2.IMREAD_UNCHANGED)
        if img is None:
            print(f"  ! Skipping unreadable file: {f}")
            continue

        rect = cv2.remap(img, mapx, mapy, interpolation=cv2.INTER_LINEAR)

        # resize to 960x600
        rect_resized = cv2.resize(rect, resize_to, interpolation=cv2.INTER_AREA)

        out_path = os.path.join(output_dir, os.path.basename(f))
        ok = cv2.imwrite(out_path, rect_resized)
        if not ok:
            print(f"  ! Failed to write: {out_path}")
        if idx % 50 == 0:
            print(f"  ...{idx} done")

# ---------------------------
# 4) Configure your folders and run
# ---------------------------
LEFT_INPUT_DIR  = "../../dataset_budapest/elte_car_stereo/dev0_70_520"
RIGHT_INPUT_DIR = "../../dataset_budapest/elte_car_stereo/dev1_70_520"

LEFT_OUTPUT_DIR  = "./rectified/dev0"
RIGHT_OUTPUT_DIR = "./rectified/dev1"

rectify_folder(LEFT_INPUT_DIR,  LEFT_OUTPUT_DIR,  map1_x, map1_y, resize_to=(960, 600))
rectify_folder(RIGHT_INPUT_DIR, RIGHT_OUTPUT_DIR, map2_x, map2_y, resize_to=(960, 600))

print("Done.")
# Out:
# P1:
#  [[1.15875000e+03 0.00000000e+00 1.08403688e+03 0.00000000e+00]
#  [0.00000000e+00 1.15875000e+03 6.17181320e+02 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
# P2:
#  [[ 1.15875000e+03  0.00000000e+00  1.08403688e+03 -1.17348074e+06]
#  [ 0.00000000e+00  1.15875000e+03  6.17181320e+02  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00]]
# [../../dataset_budapest/elte_car_stereo/dev0_70_520] -> [./rectified/dev0]  |  451 images
#   ...50 done
#   ...100 done
#   ...150 done
#   ...200 done
#   ...250 done
#   ...300 done
#   ...350 done
#   ...400 done
#   ...450 done
# [../../dataset_budapest/elte_car_stereo/dev1_70_520] -> [./rectified/dev1]  |  451 images
#   ...50 done
#   ...100 done
#   ...150 done
#   ...200 done
#   ...250 done
#   ...300 done
#   ...350 done
#   ...400 done
#   ...450 done
# Done.
